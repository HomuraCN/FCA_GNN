# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, TransformerConv
from torch_geometric.data import Data
from torch_geometric.utils import dense_to_sparse
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from datetime import datetime
from torch.utils.tensorboard import SummaryWriter

# %%
# --- 1. 超参数配置 ---
hparams = {
    'dataset': 'zoo',
    'threshold_pos': 4000,
    'threshold_neg': 49000,
    'gcn_hidden_channels': 16,
    'transformer_hidden_channels': 16,
    'heads': 4,
    'cpe_profile_bins': 8,
    'learning_rate': 0.005,
    'weight_decay': 5e-4,
    'epochs': 150,
    'dropout': 0.5,
    'seed': 42
}

# car 常用阈值: threshold_pos=500, threshold_neg=20000
# zoo 常用阈值: threshold_pos=4000, threshold_neg=49000

torch.manual_seed(hparams['seed'])
np.random.seed(hparams['seed'])

# %%
# --- 2. TensorBoard 设置 ---
timestamp = datetime.now().strftime('%Y%m%d-%H%M%S')
log_dir_name = f"../runs/{hparams['dataset']}_residual_gcn_transformer_cpe_profile{hparams['cpe_profile_bins']}_{timestamp}"
writer = SummaryWriter(log_dir_name)
print(f"TensorBoard 日志将保存在: {log_dir_name}")
# Out:
# TensorBoard 日志将保存在: ../runs/zoo_residual_gcn_transformer_cpe_profile8_20260615-165054

# %%
# --- 3. 标签、CPE 与边权处理函数 ---
def load_labels(base_path, dataset_name, expected_num_nodes):
    candidate_paths = [
        f"{base_path}{dataset_name}.data",
        f"{base_path}{dataset_name}.data.csv",
    ]

    for labels_path in candidate_paths:
        try:
            df = pd.read_csv(labels_path, header=None)
        except FileNotFoundError:
            continue

        df = df.dropna(axis=1, how='all')
        if len(df) != expected_num_nodes:
            continue
        return df.iloc[:, -1].values

    raise ValueError(f"无法读取与对象数量 {expected_num_nodes} 匹配的标签文件: {candidate_paths}")


def normalize_edge_attr(edge_attr):
    edge_attr = torch.log1p(edge_attr.float())
    if edge_attr.numel() == 0:
        return edge_attr

    min_value = edge_attr.min()
    max_value = edge_attr.max()
    if max_value > min_value:
        edge_attr = (edge_attr - min_value) / (max_value - min_value)
    return edge_attr


def load_depth_profile_cpe(base_path, dataset_name, profile_bins):
    pos_cpe_path = f"{base_path}{dataset_name}_CPE_A_plus_depth_profile{profile_bins}.csv"
    neg_cpe_path = f"{base_path}{dataset_name}_CPE_A_negative_depth_profile{profile_bins}.csv"

    cpe_pos_numpy = np.loadtxt(pos_cpe_path, delimiter=',')
    cpe_neg_numpy = np.loadtxt(neg_cpe_path, delimiter=',')

    if cpe_pos_numpy.ndim == 1:
        cpe_pos_numpy = cpe_pos_numpy.reshape(1, -1)
    if cpe_neg_numpy.ndim == 1:
        cpe_neg_numpy = cpe_neg_numpy.reshape(1, -1)

    cpe_pos = torch.tensor(cpe_pos_numpy, dtype=torch.float)
    cpe_neg = torch.tensor(cpe_neg_numpy, dtype=torch.float)
    return cpe_pos, cpe_neg

# %%
# --- 4. 数据加载与预处理函数 (原始特征 + profile8 CPE + 正负概念图) ---
def load_and_prepare_data(dataset_name, threshold_pos, threshold_neg, cpe_profile_bins):
    base_path = f'../data/{dataset_name}/'

    features_path = f"{base_path}{dataset_name}.data.cleaned.csv"
    x_numpy = np.loadtxt(features_path, delimiter=',')
    x_features = torch.tensor(x_numpy, dtype=torch.float)
    num_nodes = x_features.shape[0]

    adj_matrix_pos_path = f"{base_path}{dataset_name}_A_plus_UG.csv"
    a_plus_pos_numpy = np.loadtxt(adj_matrix_pos_path, delimiter=',')
    if a_plus_pos_numpy.shape != (num_nodes, num_nodes):
        raise ValueError(f"正概念邻接矩阵尺寸应为 {(num_nodes, num_nodes)}，实际为 {a_plus_pos_numpy.shape}")
    a_plus_pos = torch.tensor(a_plus_pos_numpy, dtype=torch.float)
    a_plus_pos[a_plus_pos <= threshold_pos] = 0
    a_plus_pos.fill_diagonal_(0)
    edge_index_pos, edge_weight_pos = dense_to_sparse(a_plus_pos)
    edge_weight_pos = normalize_edge_attr(edge_weight_pos)

    adj_matrix_neg_path = f"{base_path}{dataset_name}_A_negative_UG.csv"
    a_plus_neg_numpy = np.loadtxt(adj_matrix_neg_path, delimiter=',')
    if a_plus_neg_numpy.shape != (num_nodes, num_nodes):
        raise ValueError(f"负概念邻接矩阵尺寸应为 {(num_nodes, num_nodes)}，实际为 {a_plus_neg_numpy.shape}")
    a_plus_neg = torch.tensor(a_plus_neg_numpy, dtype=torch.float)
    a_plus_neg[a_plus_neg <= threshold_neg] = 0
    a_plus_neg.fill_diagonal_(0)
    edge_index_neg, edge_weight_neg = dense_to_sparse(a_plus_neg)
    edge_weight_neg = normalize_edge_attr(edge_weight_neg)

    cpe_pos, cpe_neg = load_depth_profile_cpe(base_path, dataset_name, cpe_profile_bins)
    if cpe_pos.shape[0] != num_nodes or cpe_neg.shape[0] != num_nodes:
        raise ValueError(
            f"CPE 行数必须和对象数量一致: num_nodes={num_nodes}, "
            f"cpe_pos={cpe_pos.shape[0]}, cpe_neg={cpe_neg.shape[0]}"
        )

    print(f"原始特征维度: {x_features.shape[1]}")
    print(f"正概念 CPE 维度: {cpe_pos.shape[1]}")
    print(f"负概念 CPE 维度: {cpe_neg.shape[1]}")
    print(f"正概念图边数: {edge_index_pos.shape[1]}")
    print(f"负概念图边数: {edge_index_neg.shape[1]}")

    labels_numpy = load_labels(base_path, dataset_name, num_nodes)

    encoder = LabelEncoder()
    y_numpy = encoder.fit_transform(labels_numpy)
    y = torch.tensor(y_numpy, dtype=torch.long)
    if num_nodes != len(y):
        raise ValueError(f"标签数量必须和对象数量一致: num_nodes={num_nodes}, labels={len(y)}")

    data = Data(
        x_raw=x_features,
        cpe_pos=cpe_pos,
        cpe_neg=cpe_neg,
        y=y,
        edge_index_pos=edge_index_pos,
        edge_weight_pos=edge_weight_pos,
        edge_attr_pos=edge_weight_pos.view(-1, 1),
        edge_index_neg=edge_index_neg,
        edge_weight_neg=edge_weight_neg,
        edge_attr_neg=edge_weight_neg.view(-1, 1),
        num_nodes=num_nodes
    )

    num_train = int(num_nodes * 0.6)
    num_val = int(num_nodes * 0.2)
    indices = torch.randperm(num_nodes)
    data.train_mask = torch.zeros(num_nodes, dtype=torch.bool); data.train_mask[indices[:num_train]] = True
    data.val_mask = torch.zeros(num_nodes, dtype=torch.bool); data.val_mask[indices[num_train:num_train + num_val]] = True
    data.test_mask = torch.zeros(num_nodes, dtype=torch.bool); data.test_mask[indices[num_train + num_val:]] = True

    return data, len(np.unique(y_numpy))

# %%
# --- 5. 定义模型 ---
class DualConceptResidualGCNTransformerWithCPE(nn.Module):
    def __init__(self,
                 raw_in_channels,
                 cpe_pos_channels,
                 cpe_neg_channels,
                 gcn_hidden_channels,
                 transformer_hidden_channels,
                 out_channels,
                 heads=1,
                 dropout=0.5):
        super(DualConceptResidualGCNTransformerWithCPE, self).__init__()
        self.dropout = dropout

        # 正负分支先分别在对应概念图上做浅层 GCN 消息传递。
        self.pos_gcn = GCNConv(raw_in_channels, gcn_hidden_channels)
        self.neg_gcn = GCNConv(raw_in_channels, gcn_hidden_channels)

        # 残差/拼接式输入：保留原始特征，再追加 GCN 局部结构表示和本分支 CPE。
        pos_transformer_in_channels = raw_in_channels + gcn_hidden_channels + cpe_pos_channels
        neg_transformer_in_channels = raw_in_channels + gcn_hidden_channels + cpe_neg_channels
        self.pos_transformer = TransformerConv(
            pos_transformer_in_channels,
            transformer_hidden_channels,
            heads=heads,
            edge_dim=1
        )
        self.neg_transformer = TransformerConv(
            neg_transformer_in_channels,
            transformer_hidden_channels,
            heads=heads,
            edge_dim=1
        )

        self.fusion_layer = nn.Linear(transformer_hidden_channels * heads * 2, out_channels)

    def forward(self,
                x_raw,
                cpe_pos,
                cpe_neg,
                edge_index_pos,
                edge_weight_pos,
                edge_attr_pos,
                edge_index_neg,
                edge_weight_neg,
                edge_attr_neg):
        h_pos_gcn = self.pos_gcn(x_raw, edge_index_pos, edge_weight=edge_weight_pos)
        h_pos_gcn = F.relu(h_pos_gcn)
        h_pos_gcn = F.dropout(h_pos_gcn, p=self.dropout, training=self.training)
        h_pos_input = torch.cat([x_raw, h_pos_gcn, cpe_pos], dim=1)

        h_neg_gcn = self.neg_gcn(x_raw, edge_index_neg, edge_weight=edge_weight_neg)
        h_neg_gcn = F.relu(h_neg_gcn)
        h_neg_gcn = F.dropout(h_neg_gcn, p=self.dropout, training=self.training)
        h_neg_input = torch.cat([x_raw, h_neg_gcn, cpe_neg], dim=1)

        h_pos = self.pos_transformer(h_pos_input, edge_index_pos, edge_attr_pos)
        h_pos = F.relu(h_pos)
        h_pos = F.dropout(h_pos, p=self.dropout, training=self.training)

        h_neg = self.neg_transformer(h_neg_input, edge_index_neg, edge_attr_neg)
        h_neg = F.relu(h_neg)
        h_neg = F.dropout(h_neg, p=self.dropout, training=self.training)

        h_combined = torch.cat([h_pos, h_neg], dim=1)
        out = self.fusion_layer(h_combined)
        return out

# %%
# --- 6. 实例化数据和模型 ---
data, num_classes = load_and_prepare_data(hparams['dataset'],
                                          hparams['threshold_pos'],
                                          hparams['threshold_neg'],
                                          hparams['cpe_profile_bins'])

model = DualConceptResidualGCNTransformerWithCPE(
    raw_in_channels=data.x_raw.shape[1],
    cpe_pos_channels=data.cpe_pos.shape[1],
    cpe_neg_channels=data.cpe_neg.shape[1],
    gcn_hidden_channels=hparams['gcn_hidden_channels'],
    transformer_hidden_channels=hparams['transformer_hidden_channels'],
    out_channels=num_classes,
    heads=hparams['heads'],
    dropout=hparams['dropout']
)

pos_transformer_input_dim = data.x_raw.shape[1] + hparams['gcn_hidden_channels'] + data.cpe_pos.shape[1]
neg_transformer_input_dim = data.x_raw.shape[1] + hparams['gcn_hidden_channels'] + data.cpe_neg.shape[1]
print(f"GCN 输入维度: {data.x_raw.shape[1]}")
print(f"GCN 输出维度: {hparams['gcn_hidden_channels']}")
print(f"正分支 Transformer 输入维度: {data.x_raw.shape[1]} + {hparams['gcn_hidden_channels']} + {data.cpe_pos.shape[1]} = {pos_transformer_input_dim}")
print(f"负分支 Transformer 输入维度: {data.x_raw.shape[1]} + {hparams['gcn_hidden_channels']} + {data.cpe_neg.shape[1]} = {neg_transformer_input_dim}")

optimizer = torch.optim.Adam(model.parameters(), lr=hparams['learning_rate'], weight_decay=hparams['weight_decay'])
criterion = torch.nn.CrossEntropyLoss()
# Out:
# 原始特征维度: 43
# 正概念 CPE 维度: 9
# 负概念 CPE 维度: 9
# 正概念图边数: 1288
# 负概念图边数: 916
# GCN 输入维度: 43
# GCN 输出维度: 16
# 正分支 Transformer 输入维度: 43 + 16 + 9 = 68
# 负分支 Transformer 输入维度: 43 + 16 + 9 = 68

# %%
# --- 7. 训练与评估函数 ---
def run_model():
    return model(
        data.x_raw,
        data.cpe_pos,
        data.cpe_neg,
        data.edge_index_pos,
        data.edge_weight_pos,
        data.edge_attr_pos,
        data.edge_index_neg,
        data.edge_weight_neg,
        data.edge_attr_neg
    )


def train(epoch):
    model.train()
    optimizer.zero_grad()
    out = run_model()
    loss = criterion(out[data.train_mask], data.y[data.train_mask])
    loss.backward()
    optimizer.step()
    writer.add_scalar('Loss/train', loss.item(), epoch)
    return loss.item()


def evaluate(epoch):
    model.eval()
    with torch.no_grad():
        out = run_model()
        pred = out.argmax(dim=1)

        train_acc = (pred[data.train_mask] == data.y[data.train_mask]).sum().item() / data.train_mask.sum().item()
        val_acc = (pred[data.val_mask] == data.y[data.val_mask]).sum().item() / data.val_mask.sum().item()
        test_acc = (pred[data.test_mask] == data.y[data.test_mask]).sum().item() / data.test_mask.sum().item()

        writer.add_scalar('Accuracy/train', train_acc, epoch)
        writer.add_scalar('Accuracy/validation', val_acc, epoch)
        writer.add_scalar('Accuracy/test', test_acc, epoch)

        return train_acc, val_acc, test_acc

# %%
# --- 8. 主训练循环 ---
print("\n--- 开始训练 (raw + GCN + profile8 CPE + 双概念格 Graph Transformer) ---")
for epoch in range(1, hparams['epochs'] + 1):
    loss = train(epoch)
    if epoch % 1 == 0:
        train_acc, val_acc, test_acc = evaluate(epoch)
        print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}, Train Acc: {train_acc:.4f}, Val Acc: {val_acc:.4f}, Test Acc: {test_acc:.4f}')

final_train_acc, final_val_acc, final_test_acc = evaluate(hparams['epochs'])
print('--- 训练完成 ---')
print(f'最终测试集准确率: {final_test_acc:.4f}')

metrics = {'accuracy/final_train': final_train_acc, 'accuracy/final_validation': final_val_acc, 'accuracy/final_test': final_test_acc}
writer.add_hparams(hparams, metrics)
writer.close()
# Out:
# --- 开始训练 (raw + GCN + profile8 CPE + 双概念格 Graph Transformer) ---
# Epoch: 001, Loss: 1.8527, Train Acc: 0.6000, Val Acc: 0.6000, Test Acc: 0.5238
# Epoch: 002, Loss: 1.5372, Train Acc: 0.6000, Val Acc: 0.6000, Test Acc: 0.5238
# Epoch: 003, Loss: 1.2961, Train Acc: 0.6167, Val Acc: 0.7000, Test Acc: 0.5714
# Epoch: 004, Loss: 1.1004, Train Acc: 0.7500, Val Acc: 0.7000, Test Acc: 0.6190
# Epoch: 005, Loss: 0.9029, Train Acc: 0.8333, Val Acc: 0.7000, Test Acc: 0.7143
# Epoch: 006, Loss: 0.8151, Train Acc: 0.8667, Val Acc: 0.7500, Test Acc: 0.7143
# Epoch: 007, Loss: 0.6415, Train Acc: 0.8667, Val Acc: 0.7500, Test Acc: 0.7143
# Epoch: 008, Loss: 0.5429, Train Acc: 0.8667, Val Acc: 0.7500, Test Acc: 0.7143
# Epoch: 009, Loss: 0.4634, Train Acc: 0.8833, Val Acc: 0.7500, Test Acc: 0.7143
# Epoch: 010, Loss: 0.4010, Train Acc: 0.8833, Val Acc: 0.8000, Test Acc: 0.7143
# Epoch: 011, Loss: 0.4031, Train Acc: 0.9167, Val Acc: 0.8500, Test Acc: 0.8095
# Epoch: 012, Loss: 0.3354, Train Acc: 0.9333, Val Acc: 0.9000, Test Acc: 0.8095
# Epoch: 013, Loss: 0.3236, Train Acc: 0.9333, Val Acc: 0.9000, Test Acc: 0.8571
# Epoch: 014, Loss: 0.2869, Train Acc: 0.9333, Val Acc: 0.9000, Test Acc: 0.8571
# Epoch: 015, Loss: 0.2311, Train Acc: 0.9500, Val Acc: 0.9000, Test Acc: 0.8571
# Epoch: 016, Loss: 0.2145, Train Acc: 0.9500, Val Acc: 0.9000, Test Acc: 0.8571
# Epoch: 017, Loss: 0.1923, Train Acc: 0.9667, Val Acc: 0.9500, Test Acc: 0.8571
# Epoch: 018, Loss: 0.1683, Train Acc: 0.9667, Val Acc: 0.9500, Test Acc: 0.8571
# Epoch: 019, Loss: 0.1597, Train Acc: 0.9667, Val Acc: 0.9500, Test Acc: 0.8571
# Epoch: 020, Loss: 0.1576, Train Acc: 0.9667, Val Acc: 0.9500, Test Acc: 0.8571
# Epoch: 021, Loss: 0.1307, Train Acc: 0.9667, Val Acc: 0.9500, Test Acc: 0.8571
# Epoch: 022, Loss: 0.1398, Train Acc: 0.9833, Val Acc: 1.0000, Test Acc: 0.8571
# Epoch: 023, Loss: 0.1412, Train Acc: 0.9833, Val Acc: 1.0000, Test Acc: 0.8571
# Epoch: 024, Loss: 0.1117, Train Acc: 0.9833, Val Acc: 1.0000, Test Acc: 0.8571
# Epoch: 025, Loss: 0.1010, Train Acc: 0.9833, Val Acc: 1.0000, Test Acc: 0.8571
# Epoch: 026, Loss: 0.0935, Train Acc: 0.9833, Val Acc: 1.0000, Test Acc: 0.8571
# Epoch: 027, Loss: 0.0940, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9048
# Epoch: 028, Loss: 0.0809, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9048
# Epoch: 029, Loss: 0.0685, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9048
# Epoch: 030, Loss: 0.0522, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 031, Loss: 0.0455, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 032, Loss: 0.0363, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 033, Loss: 0.0628, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 034, Loss: 0.0549, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 035, Loss: 0.0506, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 036, Loss: 0.0364, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 037, Loss: 0.0293, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 038, Loss: 0.0432, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 039, Loss: 0.0159, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 040, Loss: 0.0330, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 041, Loss: 0.0260, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 042, Loss: 0.0211, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 043, Loss: 0.0220, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 044, Loss: 0.0330, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 045, Loss: 0.0389, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 046, Loss: 0.0146, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 047, Loss: 0.0201, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 048, Loss: 0.0390, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 049, Loss: 0.0143, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 050, Loss: 0.0231, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 051, Loss: 0.0196, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 052, Loss: 0.0391, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 053, Loss: 0.0092, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 054, Loss: 0.0128, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 055, Loss: 0.0267, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 056, Loss: 0.0101, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 057, Loss: 0.0156, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 058, Loss: 0.0078, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 059, Loss: 0.0061, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 060, Loss: 0.0137, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 061, Loss: 0.0088, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 062, Loss: 0.0107, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 063, Loss: 0.0067, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 064, Loss: 0.0101, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 065, Loss: 0.0092, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 066, Loss: 0.0157, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 067, Loss: 0.0070, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 068, Loss: 0.0084, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 069, Loss: 0.0060, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 070, Loss: 0.0119, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 071, Loss: 0.0107, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 072, Loss: 0.0081, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 073, Loss: 0.0056, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 074, Loss: 0.0061, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 075, Loss: 0.0098, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 076, Loss: 0.0130, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 077, Loss: 0.0103, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 078, Loss: 0.0141, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 079, Loss: 0.0034, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 080, Loss: 0.0059, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 081, Loss: 0.0116, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 082, Loss: 0.0095, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 083, Loss: 0.0059, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 084, Loss: 0.0068, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 085, Loss: 0.0070, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 086, Loss: 0.0029, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 087, Loss: 0.0021, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 088, Loss: 0.0069, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 089, Loss: 0.0051, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 090, Loss: 0.0131, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 091, Loss: 0.0046, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 092, Loss: 0.0044, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 093, Loss: 0.0035, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 094, Loss: 0.0063, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 095, Loss: 0.0116, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 096, Loss: 0.0025, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 097, Loss: 0.0055, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 098, Loss: 0.0048, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 099, Loss: 0.0073, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 100, Loss: 0.0047, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 101, Loss: 0.0063, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 102, Loss: 0.0055, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 103, Loss: 0.0028, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 104, Loss: 0.0074, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 105, Loss: 0.0051, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 106, Loss: 0.0038, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 107, Loss: 0.0045, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 108, Loss: 0.0073, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 109, Loss: 0.0057, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 110, Loss: 0.0042, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 111, Loss: 0.0036, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 112, Loss: 0.0102, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 113, Loss: 0.0028, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 114, Loss: 0.0013, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 115, Loss: 0.0025, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 116, Loss: 0.0029, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 117, Loss: 0.0168, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 118, Loss: 0.0040, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 119, Loss: 0.0106, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 120, Loss: 0.0092, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 121, Loss: 0.0029, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 122, Loss: 0.0069, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 123, Loss: 0.0081, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 124, Loss: 0.0020, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 125, Loss: 0.0135, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 126, Loss: 0.0082, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 127, Loss: 0.0058, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 128, Loss: 0.0074, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 129, Loss: 0.0049, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 130, Loss: 0.0046, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 131, Loss: 0.0076, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 132, Loss: 0.0044, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 133, Loss: 0.0081, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 134, Loss: 0.0058, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 135, Loss: 0.0041, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 136, Loss: 0.0065, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 137, Loss: 0.0041, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 138, Loss: 0.0035, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 139, Loss: 0.0094, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 140, Loss: 0.0055, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 141, Loss: 0.0043, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9524
# Epoch: 142, Loss: 0.0031, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 143, Loss: 0.0024, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 144, Loss: 0.0022, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 145, Loss: 0.0018, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 146, Loss: 0.0055, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 147, Loss: 0.0021, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 148, Loss: 0.0034, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 149, Loss: 0.0040, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 150, Loss: 0.0034, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# --- 训练完成 ---
# 最终测试集准确率: 1.0000
