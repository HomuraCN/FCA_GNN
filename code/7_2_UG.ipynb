# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.data import Data
from torch_geometric.utils import dense_to_sparse
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from torch.utils.tensorboard import SummaryWriter

# --- 实例化 SummaryWriter ---
# 创建一个新的文件夹来存放本次实验的日志
writer = SummaryWriter('../runs/7_2_iris_fca_gnn_multi_curve')

# --- 数据加载与预处理 (与之前相同) ---
features_path = '../data/iris.data.cleaned.csv'
x_numpy = np.loadtxt(features_path, delimiter=',')
x = torch.tensor(x_numpy, dtype=torch.float)

adj_matrix_path = '../data/iris_A_plus_UG.csv'
a_plus_numpy = np.loadtxt(adj_matrix_path, delimiter=',')
a_plus = torch.tensor(a_plus_numpy, dtype=torch.float)
threshold = 25
a_plus[a_plus <= threshold] = 0
a_plus.fill_diagonal_(0)
edge_index, edge_attr = dense_to_sparse(a_plus)

labels_path = '../data/iris.data'
column_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
iris_df = pd.read_csv(labels_path, header=None, names=column_names)
species_labels = iris_df['species'].values
encoder = LabelEncoder()
y_numpy = encoder.fit_transform(species_labels)
y = torch.tensor(y_numpy, dtype=torch.long)

num_nodes = x.shape[0]
if num_nodes != len(y):
    y = y[:num_nodes]

data = Data(x=x, edge_index=edge_index, edge_attr=edge_attr, y=y)

# --- 数据划分：训练(60%)、验证(20%)、测试(20%) ---
num_train = int(num_nodes * 0.6)
num_val = int(num_nodes * 0.2)
num_test = num_nodes - num_train - num_val
indices = torch.randperm(num_nodes)

data.train_mask = torch.zeros(num_nodes, dtype=torch.bool)
data.val_mask = torch.zeros(num_nodes, dtype=torch.bool)
data.test_mask = torch.zeros(num_nodes, dtype=torch.bool)
data.train_mask[indices[:num_train]] = True
data.val_mask[indices[num_train:num_train + num_val]] = True
data.test_mask[indices[num_train + num_val:]] = True

print("--- 数据加载完成 ---")
print(f"训练节点数: {data.train_mask.sum().item()}, 验证节点数: {data.val_mask.sum().item()}, 测试节点数: {data.test_mask.sum().item()}")

# --- GNN 模型定义 (与之前相同) ---
class GCN(torch.nn.Module):
    def __init__(self, num_node_features, num_classes):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(num_node_features, 16)
        self.conv2 = GCNConv(16, num_classes)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.conv2(x, edge_index)
        return x

# --- 训练与评估 ---
model = GCN(num_node_features=data.num_node_features, num_classes=len(np.unique(y_numpy)))
optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-4)
criterion = torch.nn.CrossEntropyLoss()

def train(epoch):
    model.train()
    optimizer.zero_grad()
    out = model(data.x, data.edge_index)
    loss = criterion(out[data.train_mask], data.y[data.train_mask])
    loss.backward()
    optimizer.step()
    # 只记录训练集的Loss
    writer.add_scalar('Loss/train', loss.item(), epoch)
    return loss.item()

# --- 【修改】评估函数现在也计算并记录Loss ---
def evaluate(epoch):
    model.eval()
    with torch.no_grad():
        out = model(data.x, data.edge_index)
        pred = out.argmax(dim=1)
        
        # --- 计算 Loss ---
        train_loss = criterion(out[data.train_mask], data.y[data.train_mask])
        val_loss = criterion(out[data.val_mask], data.y[data.val_mask])
        test_loss = criterion(out[data.test_mask], data.y[data.test_mask])
        
        # --- 计算 Accuracy ---
        correct_train = pred[data.train_mask] == data.y[data.train_mask]
        train_acc = int(correct_train.sum()) / int(data.train_mask.sum())
        
        correct_val = pred[data.val_mask] == data.y[data.val_mask]
        val_acc = int(correct_val.sum()) / int(data.val_mask.sum())
        
        correct_test = pred[data.test_mask] == data.y[data.test_mask]
        test_acc = int(correct_test.sum()) / int(data.test_mask.sum())

        # --- 将所有指标记录到 TensorBoard ---
        # 使用相同的 "Loss" 标签头，将三条线画在同一个Loss图里
        writer.add_scalar('Loss/validation', val_loss.item(), epoch)
        writer.add_scalar('Loss/test', test_loss.item(), epoch)
        
        # 使用相同的 "Accuracy" 标签头，将三条线画在同一个Accuracy图里
        writer.add_scalar('Accuracy/train', train_acc, epoch)
        writer.add_scalar('Accuracy/validation', val_acc, epoch)
        writer.add_scalar('Accuracy/test', test_acc, epoch)
        
        return train_acc, val_acc, test_acc, train_loss.item()

print("\n--- 开始训练 ---")
for epoch in range(1, 101):
    # train()函数现在只返回loss，不再计算精度，避免重复计算
    loss = train(epoch) 
    
    # 在每个 epoch 后都进行评估
    train_acc, val_acc, test_acc, _ = evaluate(epoch)
    
    if epoch % 1 == 0:
        print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}, Train Acc: {train_acc:.4f}, Val Acc: {val_acc:.4f}, Test Acc: {test_acc:.4f}')

writer.close()

# 获取最后一个 epoch 的测试精度作为最终结果
final_test_acc = evaluate(100)[2] 
print(f'--- 训练完成 ---')
print(f'最终测试集准确率: {final_test_acc:.4f}')
print("\nTensorBoard 日志已写入 'runs' 文件夹。")
# Out:
# --- 数据加载完成 ---
# 训练节点数: 90, 验证节点数: 30, 测试节点数: 30
#
# --- 开始训练 ---
# Epoch: 001, Loss: 1.0566, Train Acc: 0.4889, Val Acc: 0.2667, Test Acc: 0.5667
# Epoch: 002, Loss: 1.0205, Train Acc: 0.5000, Val Acc: 0.2667, Test Acc: 0.5667
# Epoch: 003, Loss: 1.0450, Train Acc: 0.5222, Val Acc: 0.3000, Test Acc: 0.5667
# Epoch: 004, Loss: 1.0552, Train Acc: 0.5444, Val Acc: 0.3000, Test Acc: 0.5667
# Epoch: 005, Loss: 0.9983, Train Acc: 0.5444, Val Acc: 0.3000, Test Acc: 0.5667
# Epoch: 006, Loss: 1.0168, Train Acc: 0.5556, Val Acc: 0.3333, Test Acc: 0.5667
# Epoch: 007, Loss: 1.0302, Train Acc: 0.6111, Val Acc: 0.3667, Test Acc: 0.5667
# Epoch: 008, Loss: 1.0090, Train Acc: 0.6444, Val Acc: 0.4000, Test Acc: 0.6000
# Epoch: 009, Loss: 0.9775, Train Acc: 0.6444, Val Acc: 0.4000, Test Acc: 0.6000
# Epoch: 010, Loss: 0.9709, Train Acc: 0.6778, Val Acc: 0.4000, Test Acc: 0.6333
# Epoch: 011, Loss: 0.9663, Train Acc: 0.6778, Val Acc: 0.4000, Test Acc: 0.6667
# Epoch: 012, Loss: 0.9334, Train Acc: 0.7111, Val Acc: 0.4333, Test Acc: 0.6667
# Epoch: 013, Loss: 0.9618, Train Acc: 0.7333, Val Acc: 0.4667, Test Acc: 0.7000
# Epoch: 014, Loss: 0.9447, Train Acc: 0.7556, Val Acc: 0.5000, Test Acc: 0.7333
# Epoch: 015, Loss: 0.9622, Train Acc: 0.7667, Val Acc: 0.5000, Test Acc: 0.7333
# Epoch: 016, Loss: 0.9190, Train Acc: 0.7889, Val Acc: 0.5333, Test Acc: 0.7667
# Epoch: 017, Loss: 0.9357, Train Acc: 0.8111, Val Acc: 0.6333, Test Acc: 0.7667
# Epoch: 018, Loss: 0.9362, Train Acc: 0.8222, Val Acc: 0.6333, Test Acc: 0.8000
# Epoch: 019, Loss: 0.9000, Train Acc: 0.8556, Val Acc: 0.6333, Test Acc: 0.8333
# Epoch: 020, Loss: 0.9496, Train Acc: 0.8889, Val Acc: 0.6667, Test Acc: 0.8333
# Epoch: 021, Loss: 0.8956, Train Acc: 0.8889, Val Acc: 0.6667, Test Acc: 0.8333
# Epoch: 022, Loss: 0.8984, Train Acc: 0.8889, Val Acc: 0.7000, Test Acc: 0.8333
# Epoch: 023, Loss: 0.8591, Train Acc: 0.9111, Val Acc: 0.7000, Test Acc: 0.8333
# Epoch: 024, Loss: 0.8835, Train Acc: 0.9222, Val Acc: 0.7000, Test Acc: 0.8667
# Epoch: 025, Loss: 0.8747, Train Acc: 0.9222, Val Acc: 0.7000, Test Acc: 0.8667
# Epoch: 026, Loss: 0.8720, Train Acc: 0.9222, Val Acc: 0.7000, Test Acc: 0.8667
# Epoch: 027, Loss: 0.8580, Train Acc: 0.9333, Val Acc: 0.7000, Test Acc: 0.9000
# Epoch: 028, Loss: 0.8881, Train Acc: 0.9333, Val Acc: 0.7333, Test Acc: 0.9333
# Epoch: 029, Loss: 0.8864, Train Acc: 0.9333, Val Acc: 0.7333, Test Acc: 0.9333
# Epoch: 030, Loss: 0.8522, Train Acc: 0.9333, Val Acc: 0.7333, Test Acc: 0.9333
# Epoch: 031, Loss: 0.8490, Train Acc: 0.9333, Val Acc: 0.7667, Test Acc: 0.9333
# Epoch: 032, Loss: 0.8158, Train Acc: 0.9333, Val Acc: 0.7667, Test Acc: 0.9333
# Epoch: 033, Loss: 0.8321, Train Acc: 0.9333, Val Acc: 0.8000, Test Acc: 0.9333
# Epoch: 034, Loss: 0.8487, Train Acc: 0.9333, Val Acc: 0.8000, Test Acc: 0.9333
# Epoch: 035, Loss: 0.8497, Train Acc: 0.9333, Val Acc: 0.8000, Test Acc: 0.9333
# Epoch: 036, Loss: 0.8541, Train Acc: 0.9333, Val Acc: 0.8000, Test Acc: 0.9667
# Epoch: 037, Loss: 0.8274, Train Acc: 0.9333, Val Acc: 0.8000, Test Acc: 0.9667
# Epoch: 038, Loss: 0.7741, Train Acc: 0.9444, Val Acc: 0.8333, Test Acc: 0.9667
# Epoch: 039, Loss: 0.7755, Train Acc: 0.9444, Val Acc: 0.8667, Test Acc: 0.9667
# Epoch: 040, Loss: 0.7797, Train Acc: 0.9556, Val Acc: 0.8667, Test Acc: 0.9667
# Epoch: 041, Loss: 0.7691, Train Acc: 0.9556, Val Acc: 0.8667, Test Acc: 0.9667
# Epoch: 042, Loss: 0.7292, Train Acc: 0.9556, Val Acc: 0.8667, Test Acc: 0.9667
# Epoch: 043, Loss: 0.7477, Train Acc: 0.9667, Val Acc: 0.9000, Test Acc: 1.0000
# Epoch: 044, Loss: 0.7317, Train Acc: 0.9778, Val Acc: 0.9000, Test Acc: 1.0000
# Epoch: 045, Loss: 0.7722, Train Acc: 0.9778, Val Acc: 0.9000, Test Acc: 1.0000
# Epoch: 046, Loss: 0.7964, Train Acc: 0.9778, Val Acc: 0.9000, Test Acc: 1.0000
# Epoch: 047, Loss: 0.7081, Train Acc: 0.9778, Val Acc: 0.9000, Test Acc: 1.0000
# Epoch: 048, Loss: 0.7098, Train Acc: 0.9778, Val Acc: 0.9000, Test Acc: 1.0000
# Epoch: 049, Loss: 0.7349, Train Acc: 0.9889, Val Acc: 0.9000, Test Acc: 1.0000
# Epoch: 050, Loss: 0.7357, Train Acc: 0.9889, Val Acc: 0.9333, Test Acc: 1.0000
# Epoch: 051, Loss: 0.7237, Train Acc: 0.9889, Val Acc: 0.9333, Test Acc: 1.0000
# Epoch: 052, Loss: 0.7275, Train Acc: 0.9889, Val Acc: 0.9333, Test Acc: 1.0000
# Epoch: 053, Loss: 0.7093, Train Acc: 0.9889, Val Acc: 0.9667, Test Acc: 1.0000
# Epoch: 054, Loss: 0.6361, Train Acc: 0.9889, Val Acc: 0.9667, Test Acc: 1.0000
# Epoch: 055, Loss: 0.6820, Train Acc: 0.9889, Val Acc: 0.9667, Test Acc: 1.0000
# Epoch: 056, Loss: 0.6831, Train Acc: 0.9889, Val Acc: 0.9667, Test Acc: 1.0000
# Epoch: 057, Loss: 0.6472, Train Acc: 0.9889, Val Acc: 0.9667, Test Acc: 1.0000
# Epoch: 058, Loss: 0.7048, Train Acc: 0.9889, Val Acc: 0.9667, Test Acc: 1.0000
# Epoch: 059, Loss: 0.6568, Train Acc: 0.9889, Val Acc: 0.9667, Test Acc: 1.0000
# Epoch: 060, Loss: 0.5993, Train Acc: 0.9889, Val Acc: 0.9667, Test Acc: 1.0000
# Epoch: 061, Loss: 0.6437, Train Acc: 0.9889, Val Acc: 0.9667, Test Acc: 1.0000
# Epoch: 062, Loss: 0.6230, Train Acc: 0.9889, Val Acc: 0.9667, Test Acc: 1.0000
# Epoch: 063, Loss: 0.6200, Train Acc: 0.9889, Val Acc: 0.9667, Test Acc: 1.0000
# Epoch: 064, Loss: 0.6163, Train Acc: 0.9889, Val Acc: 0.9667, Test Acc: 1.0000
# Epoch: 065, Loss: 0.5945, Train Acc: 0.9889, Val Acc: 0.9667, Test Acc: 1.0000
# Epoch: 066, Loss: 0.5991, Train Acc: 0.9889, Val Acc: 0.9667, Test Acc: 1.0000
# Epoch: 067, Loss: 0.6054, Train Acc: 0.9889, Val Acc: 0.9667, Test Acc: 1.0000
# Epoch: 068, Loss: 0.6116, Train Acc: 0.9889, Val Acc: 0.9667, Test Acc: 1.0000
# Epoch: 069, Loss: 0.6048, Train Acc: 0.9889, Val Acc: 0.9667, Test Acc: 1.0000
# Epoch: 070, Loss: 0.5635, Train Acc: 0.9889, Val Acc: 0.9667, Test Acc: 1.0000
# Epoch: 071, Loss: 0.5586, Train Acc: 0.9889, Val Acc: 0.9667, Test Acc: 1.0000
# Epoch: 072, Loss: 0.5869, Train Acc: 1.0000, Val Acc: 0.9667, Test Acc: 1.0000
# Epoch: 073, Loss: 0.5782, Train Acc: 1.0000, Val Acc: 0.9667, Test Acc: 1.0000
# Epoch: 074, Loss: 0.5985, Train Acc: 1.0000, Val Acc: 0.9667, Test Acc: 1.0000
# Epoch: 075, Loss: 0.5453, Train Acc: 1.0000, Val Acc: 0.9667, Test Acc: 1.0000
# Epoch: 076, Loss: 0.5505, Train Acc: 1.0000, Val Acc: 0.9667, Test Acc: 1.0000
# Epoch: 077, Loss: 0.5903, Train Acc: 1.0000, Val Acc: 0.9667, Test Acc: 1.0000
# Epoch: 078, Loss: 0.5435, Train Acc: 1.0000, Val Acc: 0.9667, Test Acc: 1.0000
# Epoch: 079, Loss: 0.5481, Train Acc: 1.0000, Val Acc: 0.9667, Test Acc: 1.0000
# Epoch: 080, Loss: 0.4865, Train Acc: 1.0000, Val Acc: 0.9667, Test Acc: 1.0000
# Epoch: 081, Loss: 0.4908, Train Acc: 1.0000, Val Acc: 0.9667, Test Acc: 1.0000
# Epoch: 082, Loss: 0.4839, Train Acc: 1.0000, Val Acc: 0.9667, Test Acc: 1.0000
# Epoch: 083, Loss: 0.4861, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 084, Loss: 0.4808, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 085, Loss: 0.5001, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 086, Loss: 0.5170, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 087, Loss: 0.4642, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 088, Loss: 0.4692, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 089, Loss: 0.4782, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 090, Loss: 0.5011, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 091, Loss: 0.4557, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 092, Loss: 0.4730, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 093, Loss: 0.4562, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 094, Loss: 0.4508, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 095, Loss: 0.4042, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 096, Loss: 0.4489, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 097, Loss: 0.4377, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 098, Loss: 0.4418, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 099, Loss: 0.3974, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 100, Loss: 0.4127, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# --- 训练完成 ---
# 最终测试集准确率: 1.0000
#
# TensorBoard 日志已写入 'runs' 文件夹。
