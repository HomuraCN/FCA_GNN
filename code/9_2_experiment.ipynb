# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.data import Data
from torch_geometric.utils import dense_to_sparse
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from torch.utils.tensorboard import SummaryWriter

# %%
data_name = 'zoo'

# --- 实例化 SummaryWriter ---
writer = SummaryWriter('../runs/9_2_' + data_name)

# --- 1. 数据加载与预处理 ---

threshold_pos = 3000
threshold_neg = 49000

# a) 加载节点特征 (两个分支共享相同的节点特征)
features_path = '../data/' + data_name + '/' + data_name + '.data.cleaned.csv'
x_numpy = np.loadtxt(features_path, delimiter=',')
x_features = torch.tensor(x_numpy, dtype=torch.float)
num_nodes = x_features.shape[0]

# b) 加载并处理正概念格邻接矩阵 (分支一)
adj_matrix_pos_path = '../data/' + data_name + '/' + data_name + '_A_plus_UG.csv'
a_plus_pos_numpy = np.loadtxt(adj_matrix_pos_path, delimiter=',')
a_plus_pos = torch.tensor(a_plus_pos_numpy, dtype=torch.float)
a_plus_pos[a_plus_pos <= threshold_pos] = 0
a_plus_pos.fill_diagonal_(0)
edge_index_pos, edge_attr_pos = dense_to_sparse(a_plus_pos)
print(f"--- 正概念图 ---")
print(f"阈值化后保留 {torch.count_nonzero(a_plus_pos)} 条边。")


# c) 【新增】加载并处理负概念格邻接矩阵 (分支二)
adj_matrix_neg_path = '../data/' + data_name + '/' + data_name + '_A_negative_UG.csv'
a_plus_neg_numpy = np.loadtxt(adj_matrix_neg_path, delimiter=',')
a_plus_neg = torch.tensor(a_plus_neg_numpy, dtype=torch.float)
a_plus_neg[a_plus_neg <= threshold_neg] = 0
a_plus_neg.fill_diagonal_(0)
edge_index_neg, edge_attr_neg = dense_to_sparse(a_plus_neg)
print(f"--- 负概念图 ---")
print(f"阈值化后保留 {torch.count_nonzero(a_plus_neg)} 条边。")


# d) 加载标签 y
labels_path = '../data/' + data_name + '/' + data_name + '.data'
column_names = [
    "animal_name", "hair", "feathers", "eggs", "milk", "airborne", 
    "aquatic", "predator", "toothed", "backbone", "breathes", 
    "venomous", "fins", "legs", "tail", "domestic", "catsize", "type"
]
data_df = pd.read_csv(labels_path, header=None, names=column_names)
species_labels = data_df['type'].values
encoder = LabelEncoder()
y_numpy = encoder.fit_transform(species_labels)
y = torch.tensor(y_numpy, dtype=torch.long)
if num_nodes != len(y):
    y = y[:num_nodes]
# Out:
# --- 正概念图 ---
# 阈值化后保留 2118 条边。
# --- 负概念图 ---
# 阈值化后保留 916 条边。

# %%
# e) 创建包含所有图信息的 Data 对象
data = Data(x=x_features, y=y,
            edge_index_pos=edge_index_pos, edge_attr_pos=edge_attr_pos,
            edge_index_neg=edge_index_neg, edge_attr_neg=edge_attr_neg)

# f) 数据划分
num_train = int(num_nodes * 0.6)
num_val = int(num_nodes * 0.2)
num_test = num_nodes - num_train - num_val
indices = torch.randperm(num_nodes)
data.train_mask = torch.zeros(num_nodes, dtype=torch.bool)
data.val_mask = torch.zeros(num_nodes, dtype=torch.bool)
data.test_mask = torch.zeros(num_nodes, dtype=torch.bool)
data.train_mask[indices[:num_train]] = True
data.val_mask[indices[num_train:num_train + num_val]] = True
data.test_mask[indices[num_train + num_val:]] = True

print("\n--- 数据加载完成 (双概念格分支模型) ---")
data
# Out:
# --- 数据加载完成 (双概念格分支模型) ---
# Data(x=[101, 43], y=[101], edge_index_pos=[2, 2118], edge_attr_pos=[2118], edge_index_neg=[2, 916], edge_attr_neg=[916], train_mask=[101], val_mask=[101], test_mask=[101])

# %%
# --- 2. 定义双概念格分支 GNN 模型 (DualConceptGCN) ---
class DualConceptGCN(nn.Module):
    def __init__(self, num_node_features, hidden_channels, num_classes):
        super(DualConceptGCN, self).__init__()
        
        # 分支一：处理正概念格图
        self.pos_conv = GCNConv(num_node_features, hidden_channels)
        
        # 分支二：处理负概念格图
        self.neg_conv = GCNConv(num_node_features, hidden_channels)
        
        # 融合层
        self.fusion_layer = nn.Linear(hidden_channels * 2, num_classes)

    def forward(self, x, edge_index_pos, edge_attr_pos, edge_index_neg, edge_attr_neg):
        # --- 分支一前向传播 (正概念图) ---
        h_pos = self.pos_conv(x, edge_index_pos, edge_attr_pos)
        h_pos = F.relu(h_pos)
        h_pos = F.dropout(h_pos, p=0.5, training=self.training)
        
        # --- 分支二前向传播 (负概念图) ---
        h_neg = self.neg_conv(x, edge_index_neg, edge_attr_neg)
        h_neg = F.relu(h_neg)
        h_neg = F.dropout(h_neg, p=0.5, training=self.training)
        
        # --- 特征融合 ---
        h_combined = torch.cat([h_pos, h_neg], dim=1)
        
        # --- 通过融合层得到最终输出 ---
        out = self.fusion_layer(h_combined)
        return out

# %%
# --- 3. 训练与评估 ---
HIDDEN_CHANNELS = 16
model = DualConceptGCN(num_node_features=data.num_node_features, 
                       hidden_channels=HIDDEN_CHANNELS, 
                       num_classes=len(np.unique(y_numpy)))

optimizer = torch.optim.Adam(model.parameters(), lr=0.005, weight_decay=5e-4)
criterion = torch.nn.CrossEntropyLoss()

def train(epoch):
    model.train()
    optimizer.zero_grad()
    out = model(data.x, data.edge_index_pos, data.edge_attr_pos, 
                data.edge_index_neg, data.edge_attr_neg)
    loss = criterion(out[data.train_mask], data.y[data.train_mask])
    loss.backward()
    optimizer.step()
    writer.add_scalar('Loss/train', loss.item(), epoch)
    return loss.item()

def evaluate(epoch):
    model.eval()
    with torch.no_grad():
        out = model(data.x, data.edge_index_pos, data.edge_attr_pos, 
                    data.edge_index_neg, data.edge_attr_neg)
        pred = out.argmax(dim=1)
        
        train_acc = (pred[data.train_mask] == data.y[data.train_mask]).sum().item() / data.train_mask.sum().item()
        val_acc = (pred[data.val_mask] == data.y[data.val_mask]).sum().item() / data.val_mask.sum().item()
        test_acc = (pred[data.test_mask] == data.y[data.test_mask]).sum().item() / data.test_mask.sum().item()

        writer.add_scalar('Accuracy/train', train_acc, epoch)
        writer.add_scalar('Accuracy/validation', val_acc, epoch)
        writer.add_scalar('Accuracy/test', test_acc, epoch)
        
        return train_acc, val_acc, test_acc

print("\n--- 开始训练 (双概念格分支 GNN) ---")
for epoch in range(1, 151):
    loss = train(epoch)
    if epoch % 1 == 0:
        train_acc, val_acc, test_acc = evaluate(epoch)
        print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}, Train Acc: {train_acc:.4f}, Val Acc: {val_acc:.4f}, Test Acc: {test_acc:.4f}')

writer.close()

final_test_acc = evaluate(150)[2]
print(f'--- 训练完成 ---')
print(f'最终测试集准确率 (双概念格分支 GNN): {final_test_acc:.4f}')
print("\nTensorBoard 日志已写入 'runs/" + data_name + "_dual_concept_gnn' 文件夹。")
# Out:
# --- 开始训练 (双概念格分支 GNN) ---
# Epoch: 001, Loss: 2.0183, Train Acc: 0.0833, Val Acc: 0.1500, Test Acc: 0.1905
# Epoch: 002, Loss: 1.9389, Train Acc: 0.4333, Val Acc: 0.2500, Test Acc: 0.4762
# Epoch: 003, Loss: 1.7895, Train Acc: 0.4833, Val Acc: 0.3500, Test Acc: 0.5238
# Epoch: 004, Loss: 1.7294, Train Acc: 0.4667, Val Acc: 0.3000, Test Acc: 0.4762
# Epoch: 005, Loss: 1.6898, Train Acc: 0.5167, Val Acc: 0.3000, Test Acc: 0.4762
# Epoch: 006, Loss: 1.6160, Train Acc: 0.5167, Val Acc: 0.3000, Test Acc: 0.4762
# Epoch: 007, Loss: 1.5101, Train Acc: 0.5167, Val Acc: 0.3000, Test Acc: 0.4762
# Epoch: 008, Loss: 1.4167, Train Acc: 0.5167, Val Acc: 0.3000, Test Acc: 0.4762
# Epoch: 009, Loss: 1.3340, Train Acc: 0.5167, Val Acc: 0.3000, Test Acc: 0.4762
# Epoch: 010, Loss: 1.3238, Train Acc: 0.5500, Val Acc: 0.4000, Test Acc: 0.5238
# Epoch: 011, Loss: 1.2459, Train Acc: 0.5500, Val Acc: 0.4000, Test Acc: 0.5238
# Epoch: 012, Loss: 1.1588, Train Acc: 0.5667, Val Acc: 0.4000, Test Acc: 0.5238
# Epoch: 013, Loss: 1.1798, Train Acc: 0.6000, Val Acc: 0.4000, Test Acc: 0.5238
# Epoch: 014, Loss: 1.1341, Train Acc: 0.6333, Val Acc: 0.4000, Test Acc: 0.6190
# Epoch: 015, Loss: 1.1439, Train Acc: 0.6333, Val Acc: 0.4000, Test Acc: 0.6190
# Epoch: 016, Loss: 1.0144, Train Acc: 0.6333, Val Acc: 0.4000, Test Acc: 0.6667
# Epoch: 017, Loss: 1.0563, Train Acc: 0.7000, Val Acc: 0.4500, Test Acc: 0.6667
# Epoch: 018, Loss: 1.0381, Train Acc: 0.7333, Val Acc: 0.5000, Test Acc: 0.7619
# Epoch: 019, Loss: 0.9646, Train Acc: 0.7667, Val Acc: 0.5500, Test Acc: 0.7619
# Epoch: 020, Loss: 0.8827, Train Acc: 0.7833, Val Acc: 0.5500, Test Acc: 0.7619
# Epoch: 021, Loss: 0.8589, Train Acc: 0.7833, Val Acc: 0.5500, Test Acc: 0.7619
# Epoch: 022, Loss: 0.8455, Train Acc: 0.8000, Val Acc: 0.5500, Test Acc: 0.8095
# Epoch: 023, Loss: 0.7876, Train Acc: 0.8000, Val Acc: 0.5500, Test Acc: 0.8095
# Epoch: 024, Loss: 0.8044, Train Acc: 0.8500, Val Acc: 0.5500, Test Acc: 0.8095
# Epoch: 025, Loss: 0.7450, Train Acc: 0.8500, Val Acc: 0.6000, Test Acc: 0.8095
# Epoch: 026, Loss: 0.6114, Train Acc: 0.8500, Val Acc: 0.6000, Test Acc: 0.8095
# Epoch: 027, Loss: 0.7091, Train Acc: 0.8500, Val Acc: 0.6000, Test Acc: 0.8095
# Epoch: 028, Loss: 0.6781, Train Acc: 0.8500, Val Acc: 0.6000, Test Acc: 0.8095
# Epoch: 029, Loss: 0.6918, Train Acc: 0.8500, Val Acc: 0.6000, Test Acc: 0.8095
# Epoch: 030, Loss: 0.5826, Train Acc: 0.8667, Val Acc: 0.6000, Test Acc: 0.8095
# Epoch: 031, Loss: 0.5813, Train Acc: 0.9167, Val Acc: 0.7000, Test Acc: 0.8571
# Epoch: 032, Loss: 0.5467, Train Acc: 0.9333, Val Acc: 0.7000, Test Acc: 0.8571
# Epoch: 033, Loss: 0.5935, Train Acc: 0.9333, Val Acc: 0.7500, Test Acc: 0.8571
# Epoch: 034, Loss: 0.4990, Train Acc: 0.9333, Val Acc: 0.7500, Test Acc: 0.8571
# Epoch: 035, Loss: 0.5123, Train Acc: 0.9333, Val Acc: 0.7500, Test Acc: 0.8571
# Epoch: 036, Loss: 0.4545, Train Acc: 0.9333, Val Acc: 0.7500, Test Acc: 0.8571
# Epoch: 037, Loss: 0.5421, Train Acc: 0.9333, Val Acc: 0.7500, Test Acc: 0.8571
# Epoch: 038, Loss: 0.4421, Train Acc: 0.9333, Val Acc: 0.7500, Test Acc: 0.8571
# Epoch: 039, Loss: 0.4281, Train Acc: 0.9333, Val Acc: 0.7500, Test Acc: 0.8571
# Epoch: 040, Loss: 0.4607, Train Acc: 0.9333, Val Acc: 0.7500, Test Acc: 0.8571
# Epoch: 041, Loss: 0.3626, Train Acc: 0.9500, Val Acc: 0.7500, Test Acc: 0.8571
# Epoch: 042, Loss: 0.4651, Train Acc: 0.9500, Val Acc: 0.7500, Test Acc: 0.8571
# Epoch: 043, Loss: 0.3937, Train Acc: 0.9500, Val Acc: 0.7500, Test Acc: 0.8571
# Epoch: 044, Loss: 0.3394, Train Acc: 0.9667, Val Acc: 0.8000, Test Acc: 0.8571
# Epoch: 045, Loss: 0.4172, Train Acc: 0.9833, Val Acc: 0.8000, Test Acc: 0.8571
# Epoch: 046, Loss: 0.4238, Train Acc: 0.9833, Val Acc: 0.8000, Test Acc: 0.8571
# Epoch: 047, Loss: 0.3433, Train Acc: 0.9833, Val Acc: 0.8000, Test Acc: 0.8571
# Epoch: 048, Loss: 0.3725, Train Acc: 0.9833, Val Acc: 0.8000, Test Acc: 0.8571
# Epoch: 049, Loss: 0.3336, Train Acc: 0.9833, Val Acc: 0.8000, Test Acc: 0.9048
# Epoch: 050, Loss: 0.3257, Train Acc: 0.9833, Val Acc: 0.8000, Test Acc: 0.9048
# Epoch: 051, Loss: 0.3389, Train Acc: 0.9833, Val Acc: 0.8000, Test Acc: 0.9048
# Epoch: 052, Loss: 0.3845, Train Acc: 0.9833, Val Acc: 0.8000, Test Acc: 0.9048
# Epoch: 053, Loss: 0.3180, Train Acc: 0.9833, Val Acc: 0.8000, Test Acc: 0.9048
# Epoch: 054, Loss: 0.3158, Train Acc: 0.9833, Val Acc: 0.8000, Test Acc: 0.9048
# Epoch: 055, Loss: 0.3205, Train Acc: 0.9833, Val Acc: 0.8000, Test Acc: 0.9048
# Epoch: 056, Loss: 0.2942, Train Acc: 0.9833, Val Acc: 0.8000, Test Acc: 0.9524
# Epoch: 057, Loss: 0.2702, Train Acc: 0.9833, Val Acc: 0.8000, Test Acc: 0.9524
# Epoch: 058, Loss: 0.3193, Train Acc: 0.9833, Val Acc: 0.8000, Test Acc: 0.9524
# Epoch: 059, Loss: 0.2439, Train Acc: 0.9833, Val Acc: 0.8000, Test Acc: 0.9524
# Epoch: 060, Loss: 0.2180, Train Acc: 0.9833, Val Acc: 0.8000, Test Acc: 0.9524
# Epoch: 061, Loss: 0.3644, Train Acc: 0.9833, Val Acc: 0.8000, Test Acc: 0.9524
# Epoch: 062, Loss: 0.2347, Train Acc: 0.9833, Val Acc: 0.8000, Test Acc: 0.9524
# Epoch: 063, Loss: 0.2918, Train Acc: 0.9833, Val Acc: 0.8000, Test Acc: 0.9524
# Epoch: 064, Loss: 0.1836, Train Acc: 0.9833, Val Acc: 0.8000, Test Acc: 0.9524
# Epoch: 065, Loss: 0.2903, Train Acc: 0.9833, Val Acc: 0.8000, Test Acc: 0.9524
# Epoch: 066, Loss: 0.2905, Train Acc: 0.9833, Val Acc: 0.8000, Test Acc: 0.9524
# Epoch: 067, Loss: 0.2335, Train Acc: 0.9833, Val Acc: 0.8000, Test Acc: 0.9048
# Epoch: 068, Loss: 0.1134, Train Acc: 0.9833, Val Acc: 0.8500, Test Acc: 0.9048
# Epoch: 069, Loss: 0.2203, Train Acc: 0.9833, Val Acc: 0.8500, Test Acc: 0.9048
# Epoch: 070, Loss: 0.2061, Train Acc: 0.9833, Val Acc: 0.8500, Test Acc: 0.9048
# Epoch: 071, Loss: 0.2115, Train Acc: 0.9833, Val Acc: 0.8500, Test Acc: 0.9048
# Epoch: 072, Loss: 0.1852, Train Acc: 0.9833, Val Acc: 0.8500, Test Acc: 0.9048
# Epoch: 073, Loss: 0.2855, Train Acc: 0.9833, Val Acc: 0.8500, Test Acc: 0.9048
# Epoch: 074, Loss: 0.2185, Train Acc: 1.0000, Val Acc: 0.8500, Test Acc: 0.9048
# Epoch: 075, Loss: 0.2698, Train Acc: 1.0000, Val Acc: 0.8500, Test Acc: 0.9048
# Epoch: 076, Loss: 0.3011, Train Acc: 1.0000, Val Acc: 0.9000, Test Acc: 0.9048
# Epoch: 077, Loss: 0.2928, Train Acc: 1.0000, Val Acc: 0.9000, Test Acc: 0.9048
# Epoch: 078, Loss: 0.1896, Train Acc: 1.0000, Val Acc: 0.9000, Test Acc: 0.9048
# Epoch: 079, Loss: 0.2328, Train Acc: 1.0000, Val Acc: 0.9000, Test Acc: 0.9048
# Epoch: 080, Loss: 0.1382, Train Acc: 1.0000, Val Acc: 0.9000, Test Acc: 1.0000
# Epoch: 081, Loss: 0.1866, Train Acc: 1.0000, Val Acc: 0.9000, Test Acc: 1.0000
# Epoch: 082, Loss: 0.2059, Train Acc: 1.0000, Val Acc: 0.9000, Test Acc: 1.0000
# Epoch: 083, Loss: 0.2079, Train Acc: 1.0000, Val Acc: 0.9000, Test Acc: 1.0000
# Epoch: 084, Loss: 0.1943, Train Acc: 1.0000, Val Acc: 0.9000, Test Acc: 1.0000
# Epoch: 085, Loss: 0.2075, Train Acc: 1.0000, Val Acc: 0.9000, Test Acc: 1.0000
# Epoch: 086, Loss: 0.2422, Train Acc: 1.0000, Val Acc: 0.9000, Test Acc: 1.0000
# Epoch: 087, Loss: 0.1762, Train Acc: 1.0000, Val Acc: 0.9000, Test Acc: 1.0000
# Epoch: 088, Loss: 0.1611, Train Acc: 1.0000, Val Acc: 0.9000, Test Acc: 1.0000
# Epoch: 089, Loss: 0.1557, Train Acc: 1.0000, Val Acc: 0.9000, Test Acc: 1.0000
# Epoch: 090, Loss: 0.1714, Train Acc: 1.0000, Val Acc: 0.9000, Test Acc: 1.0000
# Epoch: 091, Loss: 0.2571, Train Acc: 1.0000, Val Acc: 0.9000, Test Acc: 1.0000
# Epoch: 092, Loss: 0.1150, Train Acc: 1.0000, Val Acc: 0.9000, Test Acc: 1.0000
# Epoch: 093, Loss: 0.1994, Train Acc: 1.0000, Val Acc: 0.9000, Test Acc: 1.0000
# Epoch: 094, Loss: 0.1537, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 095, Loss: 0.1354, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 096, Loss: 0.1732, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 097, Loss: 0.1207, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 098, Loss: 0.2333, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 099, Loss: 0.2384, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 100, Loss: 0.1577, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 101, Loss: 0.0975, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 102, Loss: 0.1572, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 103, Loss: 0.1521, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 104, Loss: 0.2028, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 105, Loss: 0.2586, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 106, Loss: 0.1712, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 107, Loss: 0.1268, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 108, Loss: 0.1285, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 109, Loss: 0.1139, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 110, Loss: 0.1623, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 111, Loss: 0.1844, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 112, Loss: 0.1520, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 113, Loss: 0.1429, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 114, Loss: 0.1291, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 115, Loss: 0.1105, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 116, Loss: 0.1215, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 117, Loss: 0.1497, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 118, Loss: 0.1619, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 119, Loss: 0.1236, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 120, Loss: 0.1381, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 121, Loss: 0.1031, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 122, Loss: 0.1223, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 123, Loss: 0.1308, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 124, Loss: 0.0788, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 125, Loss: 0.1373, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 126, Loss: 0.1463, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 127, Loss: 0.1317, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 128, Loss: 0.1571, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 129, Loss: 0.1187, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 130, Loss: 0.1244, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 131, Loss: 0.0800, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 132, Loss: 0.0838, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 133, Loss: 0.1237, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 134, Loss: 0.1176, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 135, Loss: 0.0739, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 136, Loss: 0.1380, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 137, Loss: 0.1287, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 138, Loss: 0.1814, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 139, Loss: 0.1259, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 140, Loss: 0.1306, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 141, Loss: 0.1019, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 142, Loss: 0.1942, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 143, Loss: 0.1092, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 144, Loss: 0.0854, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 145, Loss: 0.1445, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 146, Loss: 0.0718, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 147, Loss: 0.1391, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 148, Loss: 0.0798, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 149, Loss: 0.1034, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 150, Loss: 0.1264, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# --- 训练完成 ---
# 最终测试集准确率 (双概念格分支 GNN): 1.0000
#
# TensorBoard 日志已写入 'runs/zoo_dual_concept_gnn' 文件夹。
