# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.data import Data
from torch_geometric.utils import dense_to_sparse
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from torch.utils.tensorboard import SummaryWriter

# %%
data_name = 'zoo'

# --- 实例化 SummaryWriter ---
writer = SummaryWriter('../runs/9_2_' + data_name)

# --- 1. 数据加载与预处理 ---

threshold_pos = 3000
threshold_neg = 49000

# a) 加载节点特征 (两个分支共享相同的节点特征)
features_path = '../data/' + data_name + '/' + data_name + '.data.cleaned.csv'
x_numpy = np.loadtxt(features_path, delimiter=',')
x_features = torch.tensor(x_numpy, dtype=torch.float)
num_nodes = x_features.shape[0]

# b) 加载并处理正概念格邻接矩阵 (分支一)
adj_matrix_pos_path = '../data/' + data_name + '/' + data_name + '_A_plus_UG.csv'
a_plus_pos_numpy = np.loadtxt(adj_matrix_pos_path, delimiter=',')
a_plus_pos = torch.tensor(a_plus_pos_numpy, dtype=torch.float)
a_plus_pos[a_plus_pos <= threshold_pos] = 0
a_plus_pos.fill_diagonal_(0)
edge_index_pos, edge_attr_pos = dense_to_sparse(a_plus_pos)
print(f"--- 正概念图 ---")
print(f"阈值化后保留 {torch.count_nonzero(a_plus_pos)} 条边。")


# c) 【新增】加载并处理负概念格邻接矩阵 (分支二)
adj_matrix_neg_path = '../data/' + data_name + '/' + data_name + '_A_negative_UG.csv'
a_plus_neg_numpy = np.loadtxt(adj_matrix_neg_path, delimiter=',')
a_plus_neg = torch.tensor(a_plus_neg_numpy, dtype=torch.float)
a_plus_neg[a_plus_neg <= threshold_neg] = 0
a_plus_neg.fill_diagonal_(0)
edge_index_neg, edge_attr_neg = dense_to_sparse(a_plus_neg)
print(f"--- 负概念图 ---")
print(f"阈值化后保留 {torch.count_nonzero(a_plus_neg)} 条边。")


# d) 加载标签 y
labels_path = '../data/' + data_name + '/' + data_name + '.data'
column_names = [
    "animal_name", "hair", "feathers", "eggs", "milk", "airborne", 
    "aquatic", "predator", "toothed", "backbone", "breathes", 
    "venomous", "fins", "legs", "tail", "domestic", "catsize", "type"
]
data_df = pd.read_csv(labels_path, header=None, names=column_names)
species_labels = data_df['type'].values
encoder = LabelEncoder()
y_numpy = encoder.fit_transform(species_labels)
y = torch.tensor(y_numpy, dtype=torch.long)
if num_nodes != len(y):
    y = y[:num_nodes]
# Out:
# --- 正概念图 ---
# 阈值化后保留 2118 条边。
# --- 负概念图 ---
# 阈值化后保留 916 条边。

# %%
# e) 创建包含所有图信息的 Data 对象
data = Data(x=x_features, y=y,
            edge_index_pos=edge_index_pos, edge_attr_pos=edge_attr_pos,
            edge_index_neg=edge_index_neg, edge_attr_neg=edge_attr_neg)

# f) 数据划分
num_train = int(num_nodes * 0.6)
num_val = int(num_nodes * 0.2)
num_test = num_nodes - num_train - num_val
indices = torch.randperm(num_nodes)
data.train_mask = torch.zeros(num_nodes, dtype=torch.bool)
data.val_mask = torch.zeros(num_nodes, dtype=torch.bool)
data.test_mask = torch.zeros(num_nodes, dtype=torch.bool)
data.train_mask[indices[:num_train]] = True
data.val_mask[indices[num_train:num_train + num_val]] = True
data.test_mask[indices[num_train + num_val:]] = True

print("\n--- 数据加载完成 (双概念格分支模型) ---")
data
# Out:
# --- 数据加载完成 (双概念格分支模型) ---
# Data(x=[101, 43], y=[101], edge_index_pos=[2, 2118], edge_attr_pos=[2118], edge_index_neg=[2, 916], edge_attr_neg=[916], train_mask=[101], val_mask=[101], test_mask=[101])

# %%
# --- 2. 定义双概念格分支 GNN 模型 (DualConceptGCN) ---
class DualConceptGCN(nn.Module):
    def __init__(self, num_node_features, hidden_channels, num_classes):
        super(DualConceptGCN, self).__init__()
        
        # 分支一：处理正概念格图
        self.pos_conv = GCNConv(num_node_features, hidden_channels)
        
        # 分支二：处理负概念格图
        self.neg_conv = GCNConv(num_node_features, hidden_channels)
        
        # 融合层
        self.fusion_layer = nn.Linear(hidden_channels * 2, num_classes)

    def forward(self, x, edge_index_pos, edge_attr_pos, edge_index_neg, edge_attr_neg):
        # --- 分支一前向传播 (正概念图) ---
        h_pos = self.pos_conv(x, edge_index_pos, edge_attr_pos)
        h_pos = F.relu(h_pos)
        h_pos = F.dropout(h_pos, p=0.5, training=self.training)
        
        # --- 分支二前向传播 (负概念图) ---
        h_neg = self.neg_conv(x, edge_index_neg, edge_attr_neg)
        h_neg = F.relu(h_neg)
        h_neg = F.dropout(h_neg, p=0.5, training=self.training)
        
        # --- 特征融合 ---
        h_combined = torch.cat([h_pos, h_neg], dim=1)
        
        # --- 通过融合层得到最终输出 ---
        out = self.fusion_layer(h_combined)
        return out

# %%
# --- 3. 训练与评估 ---
HIDDEN_CHANNELS = 16
model = DualConceptGCN(num_node_features=data.num_node_features, 
                       hidden_channels=HIDDEN_CHANNELS, 
                       num_classes=len(np.unique(y_numpy)))

optimizer = torch.optim.Adam(model.parameters(), lr=0.005, weight_decay=5e-4)
criterion = torch.nn.CrossEntropyLoss()

def train(epoch):
    model.train()
    optimizer.zero_grad()
    out = model(data.x, data.edge_index_pos, data.edge_attr_pos, 
                data.edge_index_neg, data.edge_attr_neg)
    loss = criterion(out[data.train_mask], data.y[data.train_mask])
    loss.backward()
    optimizer.step()
    writer.add_scalar('Loss/train', loss.item(), epoch)
    return loss.item()

def evaluate(epoch):
    model.eval()
    with torch.no_grad():
        out = model(data.x, data.edge_index_pos, data.edge_attr_pos, 
                    data.edge_index_neg, data.edge_attr_neg)
        pred = out.argmax(dim=1)
        
        train_acc = (pred[data.train_mask] == data.y[data.train_mask]).sum().item() / data.train_mask.sum().item()
        val_acc = (pred[data.val_mask] == data.y[data.val_mask]).sum().item() / data.val_mask.sum().item()
        test_acc = (pred[data.test_mask] == data.y[data.test_mask]).sum().item() / data.test_mask.sum().item()

        writer.add_scalar('Accuracy/train', train_acc, epoch)
        writer.add_scalar('Accuracy/validation', val_acc, epoch)
        writer.add_scalar('Accuracy/test', test_acc, epoch)
        
        return train_acc, val_acc, test_acc

print("\n--- 开始训练 (双概念格分支 GNN) ---")
for epoch in range(1, 151):
    loss = train(epoch)
    if epoch % 1 == 0:
        train_acc, val_acc, test_acc = evaluate(epoch)
        print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}, Train Acc: {train_acc:.4f}, Val Acc: {val_acc:.4f}, Test Acc: {test_acc:.4f}')

writer.close()

final_test_acc = evaluate(150)[2]
print(f'--- 训练完成 ---')
print(f'最终测试集准确率 (双概念格分支 GNN): {final_test_acc:.4f}')
print("\nTensorBoard 日志已写入 'runs/" + data_name + "_dual_concept_gnn' 文件夹。")
# Out:
# --- 开始训练 (双概念格分支 GNN) ---
# Epoch: 001, Loss: 2.0890, Train Acc: 0.1333, Val Acc: 0.1500, Test Acc: 0.0476
# Epoch: 002, Loss: 1.9837, Train Acc: 0.3000, Val Acc: 0.3500, Test Acc: 0.4286
# Epoch: 003, Loss: 1.8250, Train Acc: 0.4500, Val Acc: 0.4500, Test Acc: 0.5714
# Epoch: 004, Loss: 1.7447, Train Acc: 0.6000, Val Acc: 0.6000, Test Acc: 0.8095
# Epoch: 005, Loss: 1.7379, Train Acc: 0.6500, Val Acc: 0.6500, Test Acc: 0.8571
# Epoch: 006, Loss: 1.6845, Train Acc: 0.6500, Val Acc: 0.6500, Test Acc: 0.8571
# Epoch: 007, Loss: 1.6099, Train Acc: 0.5667, Val Acc: 0.6000, Test Acc: 0.8571
# Epoch: 008, Loss: 1.5049, Train Acc: 0.5333, Val Acc: 0.6000, Test Acc: 0.8095
# Epoch: 009, Loss: 1.5027, Train Acc: 0.5333, Val Acc: 0.6000, Test Acc: 0.8095
# Epoch: 010, Loss: 1.5071, Train Acc: 0.5333, Val Acc: 0.6000, Test Acc: 0.8095
# Epoch: 011, Loss: 1.3125, Train Acc: 0.5500, Val Acc: 0.6000, Test Acc: 0.8095
# Epoch: 012, Loss: 1.2578, Train Acc: 0.5500, Val Acc: 0.6000, Test Acc: 0.8095
# Epoch: 013, Loss: 1.2183, Train Acc: 0.5833, Val Acc: 0.6000, Test Acc: 0.8095
# Epoch: 014, Loss: 1.2382, Train Acc: 0.5833, Val Acc: 0.6000, Test Acc: 0.8095
# Epoch: 015, Loss: 1.2180, Train Acc: 0.6000, Val Acc: 0.6000, Test Acc: 0.8095
# Epoch: 016, Loss: 1.1274, Train Acc: 0.6333, Val Acc: 0.6500, Test Acc: 0.8095
# Epoch: 017, Loss: 1.2056, Train Acc: 0.6500, Val Acc: 0.6500, Test Acc: 0.8095
# Epoch: 018, Loss: 1.0433, Train Acc: 0.7000, Val Acc: 0.8000, Test Acc: 0.8095
# Epoch: 019, Loss: 1.0211, Train Acc: 0.7500, Val Acc: 0.8000, Test Acc: 0.8095
# Epoch: 020, Loss: 1.0799, Train Acc: 0.7500, Val Acc: 0.8000, Test Acc: 0.8095
# Epoch: 021, Loss: 0.9235, Train Acc: 0.8167, Val Acc: 0.8500, Test Acc: 0.8571
# Epoch: 022, Loss: 0.9423, Train Acc: 0.8667, Val Acc: 0.8500, Test Acc: 0.8571
# Epoch: 023, Loss: 0.8961, Train Acc: 0.8667, Val Acc: 0.9000, Test Acc: 0.8571
# Epoch: 024, Loss: 0.8344, Train Acc: 0.8667, Val Acc: 0.9500, Test Acc: 0.8571
# Epoch: 025, Loss: 0.8169, Train Acc: 0.8667, Val Acc: 0.9500, Test Acc: 0.8571
# Epoch: 026, Loss: 0.7966, Train Acc: 0.8667, Val Acc: 0.9500, Test Acc: 0.8571
# Epoch: 027, Loss: 0.8212, Train Acc: 0.8667, Val Acc: 0.9500, Test Acc: 0.8571
# Epoch: 028, Loss: 0.7898, Train Acc: 0.9000, Val Acc: 0.9500, Test Acc: 0.8571
# Epoch: 029, Loss: 0.6835, Train Acc: 0.9000, Val Acc: 0.9500, Test Acc: 0.8571
# Epoch: 030, Loss: 0.7019, Train Acc: 0.9000, Val Acc: 0.9500, Test Acc: 0.8571
# Epoch: 031, Loss: 0.6598, Train Acc: 0.9000, Val Acc: 0.9500, Test Acc: 0.8571
# Epoch: 032, Loss: 0.6497, Train Acc: 0.9000, Val Acc: 0.9500, Test Acc: 0.8571
# Epoch: 033, Loss: 0.6488, Train Acc: 0.9167, Val Acc: 0.9500, Test Acc: 0.8571
# Epoch: 034, Loss: 0.6089, Train Acc: 0.9333, Val Acc: 0.9500, Test Acc: 0.8571
# Epoch: 035, Loss: 0.5903, Train Acc: 0.9333, Val Acc: 0.9500, Test Acc: 0.8571
# Epoch: 036, Loss: 0.5731, Train Acc: 0.9333, Val Acc: 0.9500, Test Acc: 0.8571
# Epoch: 037, Loss: 0.5855, Train Acc: 0.9667, Val Acc: 0.9500, Test Acc: 0.8571
# Epoch: 038, Loss: 0.6178, Train Acc: 0.9667, Val Acc: 0.9500, Test Acc: 0.8571
# Epoch: 039, Loss: 0.5942, Train Acc: 0.9667, Val Acc: 0.9500, Test Acc: 0.8571
# Epoch: 040, Loss: 0.6402, Train Acc: 0.9667, Val Acc: 0.9500, Test Acc: 0.9048
# Epoch: 041, Loss: 0.5849, Train Acc: 0.9667, Val Acc: 0.9500, Test Acc: 0.9048
# Epoch: 042, Loss: 0.5950, Train Acc: 0.9667, Val Acc: 0.9500, Test Acc: 0.9048
# Epoch: 043, Loss: 0.3815, Train Acc: 0.9667, Val Acc: 0.9500, Test Acc: 0.9048
# Epoch: 044, Loss: 0.5031, Train Acc: 0.9833, Val Acc: 0.9500, Test Acc: 0.9048
# Epoch: 045, Loss: 0.4905, Train Acc: 0.9833, Val Acc: 0.9500, Test Acc: 0.9048
# Epoch: 046, Loss: 0.4455, Train Acc: 0.9833, Val Acc: 0.9500, Test Acc: 0.9048
# Epoch: 047, Loss: 0.4466, Train Acc: 0.9833, Val Acc: 0.9500, Test Acc: 0.9048
# Epoch: 048, Loss: 0.4012, Train Acc: 0.9833, Val Acc: 0.9500, Test Acc: 0.9048
# Epoch: 049, Loss: 0.6082, Train Acc: 0.9833, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 050, Loss: 0.4328, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 051, Loss: 0.4171, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 052, Loss: 0.4452, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 053, Loss: 0.4073, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 054, Loss: 0.3857, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 055, Loss: 0.4422, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 056, Loss: 0.3592, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 057, Loss: 0.2974, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 058, Loss: 0.2437, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 059, Loss: 0.3135, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 060, Loss: 0.3329, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 061, Loss: 0.3087, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 062, Loss: 0.4197, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 063, Loss: 0.3417, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 064, Loss: 0.2877, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 065, Loss: 0.3124, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 066, Loss: 0.3379, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 067, Loss: 0.3334, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 068, Loss: 0.3034, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 069, Loss: 0.3042, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 070, Loss: 0.2756, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 071, Loss: 0.2239, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 072, Loss: 0.2624, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 073, Loss: 0.3008, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 074, Loss: 0.1745, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 075, Loss: 0.3148, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 076, Loss: 0.2434, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 077, Loss: 0.2683, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 078, Loss: 0.1858, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 079, Loss: 0.2363, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 080, Loss: 0.2042, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 081, Loss: 0.2144, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 082, Loss: 0.2460, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 083, Loss: 0.2356, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 084, Loss: 0.2834, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 085, Loss: 0.1758, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 086, Loss: 0.1513, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 087, Loss: 0.2155, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 088, Loss: 0.2004, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 089, Loss: 0.2155, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 090, Loss: 0.2520, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 091, Loss: 0.2328, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 092, Loss: 0.1765, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 093, Loss: 0.2123, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 094, Loss: 0.2309, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 095, Loss: 0.1910, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 096, Loss: 0.2229, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 097, Loss: 0.1708, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 098, Loss: 0.1994, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 099, Loss: 0.1951, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 100, Loss: 0.1420, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 101, Loss: 0.2338, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 102, Loss: 0.1369, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 103, Loss: 0.1767, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 104, Loss: 0.1615, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 105, Loss: 0.1719, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 106, Loss: 0.1703, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 107, Loss: 0.0861, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 108, Loss: 0.1744, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 109, Loss: 0.1573, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 110, Loss: 0.1069, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 111, Loss: 0.1316, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 112, Loss: 0.1568, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 113, Loss: 0.1889, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 114, Loss: 0.1287, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 115, Loss: 0.0924, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 116, Loss: 0.1213, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 117, Loss: 0.2018, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 118, Loss: 0.1951, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 119, Loss: 0.1687, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 120, Loss: 0.1158, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 121, Loss: 0.1756, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 122, Loss: 0.0922, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 123, Loss: 0.1582, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 124, Loss: 0.1121, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 125, Loss: 0.1456, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 126, Loss: 0.1971, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 127, Loss: 0.1438, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 128, Loss: 0.1013, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 129, Loss: 0.1364, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 0.9524
# Epoch: 130, Loss: 0.1143, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 131, Loss: 0.0878, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 132, Loss: 0.1403, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 133, Loss: 0.1109, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 134, Loss: 0.0647, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 135, Loss: 0.0757, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 136, Loss: 0.1542, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 137, Loss: 0.1502, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 138, Loss: 0.0793, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 139, Loss: 0.1163, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 140, Loss: 0.0692, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 141, Loss: 0.0753, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 142, Loss: 0.1314, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 143, Loss: 0.0910, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 144, Loss: 0.1735, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 145, Loss: 0.1473, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 146, Loss: 0.1144, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 147, Loss: 0.0841, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 148, Loss: 0.0648, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 149, Loss: 0.0789, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# Epoch: 150, Loss: 0.1496, Train Acc: 1.0000, Val Acc: 0.9500, Test Acc: 1.0000
# --- 训练完成 ---
# 最终测试集准确率 (双概念格分支 GNN): 1.0000
#
# TensorBoard 日志已写入 'runs/zoo_dual_concept_gnn' 文件夹。
