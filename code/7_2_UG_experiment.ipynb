# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.data import Data
from torch_geometric.utils import dense_to_sparse
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from torch.utils.tensorboard import SummaryWriter

# --- 实例化 SummaryWriter ---
# 创建一个新的文件夹来存放本次实验的日志
writer = SummaryWriter('../runs/7_2_iris_obj_attr_fca_gnn_multi_curve')

# --- 数据加载与预处理 (与之前相同) ---
features_path = '../data/iris/iris.data.cleaned.csv'
x_numpy = np.loadtxt(features_path, delimiter=',')
x = torch.tensor(x_numpy, dtype=torch.float)

adj_matrix_path = '../data/iris/iris_obj_attr_A_plus_UG.csv'
a_plus_numpy = np.loadtxt(adj_matrix_path, delimiter=',')
a_plus = torch.tensor(a_plus_numpy, dtype=torch.float)
threshold = 0
a_plus[a_plus <= threshold] = 0
a_plus.fill_diagonal_(0)
edge_index, edge_attr = dense_to_sparse(a_plus)

labels_path = '../data/iris/iris.data'
column_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
iris_df = pd.read_csv(labels_path, header=None, names=column_names)
species_labels = iris_df['species'].values
encoder = LabelEncoder()
y_numpy = encoder.fit_transform(species_labels)
y = torch.tensor(y_numpy, dtype=torch.long)

num_nodes = x.shape[0]
if num_nodes != len(y):
    y = y[:num_nodes]

data = Data(x=x, edge_index=edge_index, edge_attr=edge_attr, y=y)

# --- 数据划分：训练(60%)、验证(20%)、测试(20%) ---
num_train = int(num_nodes * 0.6)
num_val = int(num_nodes * 0.2)
num_test = num_nodes - num_train - num_val
indices = torch.randperm(num_nodes)

data.train_mask = torch.zeros(num_nodes, dtype=torch.bool)
data.val_mask = torch.zeros(num_nodes, dtype=torch.bool)
data.test_mask = torch.zeros(num_nodes, dtype=torch.bool)
data.train_mask[indices[:num_train]] = True
data.val_mask[indices[num_train:num_train + num_val]] = True
data.test_mask[indices[num_train + num_val:]] = True

print("--- 数据加载完成 ---")
print(f"训练节点数: {data.train_mask.sum().item()}, 验证节点数: {data.val_mask.sum().item()}, 测试节点数: {data.test_mask.sum().item()}")

# --- GNN 模型定义 (与之前相同) ---
class GCN(torch.nn.Module):
    def __init__(self, num_node_features, num_classes):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(num_node_features, 16)
        self.conv2 = GCNConv(16, num_classes)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.conv2(x, edge_index)
        return x

# --- 训练与评估 ---
model = GCN(num_node_features=data.num_node_features, num_classes=len(np.unique(y_numpy)))
optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-4)
criterion = torch.nn.CrossEntropyLoss()

def train(epoch):
    model.train()
    optimizer.zero_grad()
    out = model(data.x, data.edge_index)
    loss = criterion(out[data.train_mask], data.y[data.train_mask])
    loss.backward()
    optimizer.step()
    # 只记录训练集的Loss
    writer.add_scalar('Loss/train', loss.item(), epoch)
    return loss.item()

# --- 【修改】评估函数现在也计算并记录Loss ---
def evaluate(epoch):
    model.eval()
    with torch.no_grad():
        out = model(data.x, data.edge_index)
        pred = out.argmax(dim=1)
        
        # --- 计算 Loss ---
        train_loss = criterion(out[data.train_mask], data.y[data.train_mask])
        val_loss = criterion(out[data.val_mask], data.y[data.val_mask])
        test_loss = criterion(out[data.test_mask], data.y[data.test_mask])
        
        # --- 计算 Accuracy ---
        correct_train = pred[data.train_mask] == data.y[data.train_mask]
        train_acc = int(correct_train.sum()) / int(data.train_mask.sum())
        
        correct_val = pred[data.val_mask] == data.y[data.val_mask]
        val_acc = int(correct_val.sum()) / int(data.val_mask.sum())
        
        correct_test = pred[data.test_mask] == data.y[data.test_mask]
        test_acc = int(correct_test.sum()) / int(data.test_mask.sum())

        # --- 将所有指标记录到 TensorBoard ---
        # 使用相同的 "Loss" 标签头，将三条线画在同一个Loss图里
        writer.add_scalar('Loss/validation', val_loss.item(), epoch)
        writer.add_scalar('Loss/test', test_loss.item(), epoch)
        
        # 使用相同的 "Accuracy" 标签头，将三条线画在同一个Accuracy图里
        writer.add_scalar('Accuracy/train', train_acc, epoch)
        writer.add_scalar('Accuracy/validation', val_acc, epoch)
        writer.add_scalar('Accuracy/test', test_acc, epoch)
        
        return train_acc, val_acc, test_acc, train_loss.item()

print("\n--- 开始训练 ---")
for epoch in range(1, 101):
    # train()函数现在只返回loss，不再计算精度，避免重复计算
    loss = train(epoch) 
    
    # 在每个 epoch 后都进行评估
    train_acc, val_acc, test_acc, _ = evaluate(epoch)
    
    if epoch % 1 == 0:
        print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}, Train Acc: {train_acc:.4f}, Val Acc: {val_acc:.4f}, Test Acc: {test_acc:.4f}')

writer.close()

# 获取最后一个 epoch 的测试精度作为最终结果
final_test_acc = evaluate(100)[2] 
print(f'--- 训练完成 ---')
print(f'最终测试集准确率: {final_test_acc:.4f}')
print("\nTensorBoard 日志已写入 'runs' 文件夹。")
# Out:
# --- 数据加载完成 ---
# 训练节点数: 90, 验证节点数: 30, 测试节点数: 30
#
# --- 开始训练 ---
# Epoch: 001, Loss: 1.0988, Train Acc: 0.0111, Val Acc: 0.0000, Test Acc: 0.0000
# Epoch: 002, Loss: 1.0874, Train Acc: 0.1222, Val Acc: 0.1000, Test Acc: 0.1000
# Epoch: 003, Loss: 1.0711, Train Acc: 0.4000, Val Acc: 0.2667, Test Acc: 0.2000
# Epoch: 004, Loss: 1.0569, Train Acc: 0.4000, Val Acc: 0.2667, Test Acc: 0.2000
# Epoch: 005, Loss: 1.0588, Train Acc: 0.4000, Val Acc: 0.2667, Test Acc: 0.2000
# Epoch: 006, Loss: 1.0594, Train Acc: 0.4000, Val Acc: 0.2667, Test Acc: 0.2000
# Epoch: 007, Loss: 1.0403, Train Acc: 0.4000, Val Acc: 0.2667, Test Acc: 0.2000
# Epoch: 008, Loss: 1.0331, Train Acc: 0.4000, Val Acc: 0.2667, Test Acc: 0.2000
# Epoch: 009, Loss: 1.0186, Train Acc: 0.4000, Val Acc: 0.2667, Test Acc: 0.2000
# Epoch: 010, Loss: 1.0237, Train Acc: 0.4000, Val Acc: 0.2667, Test Acc: 0.2000
# Epoch: 011, Loss: 1.0095, Train Acc: 0.5333, Val Acc: 0.4667, Test Acc: 0.3000
# Epoch: 012, Loss: 0.9959, Train Acc: 0.6111, Val Acc: 0.6000, Test Acc: 0.3667
# Epoch: 013, Loss: 1.0062, Train Acc: 0.6556, Val Acc: 0.6333, Test Acc: 0.3667
# Epoch: 014, Loss: 0.9975, Train Acc: 0.6556, Val Acc: 0.6667, Test Acc: 0.3667
# Epoch: 015, Loss: 0.9914, Train Acc: 0.6778, Val Acc: 0.7333, Test Acc: 0.4000
# Epoch: 016, Loss: 0.9823, Train Acc: 0.6778, Val Acc: 0.7333, Test Acc: 0.4000
# Epoch: 017, Loss: 0.9591, Train Acc: 0.6778, Val Acc: 0.7333, Test Acc: 0.4000
# Epoch: 018, Loss: 0.9603, Train Acc: 0.6778, Val Acc: 0.7333, Test Acc: 0.4000
# Epoch: 019, Loss: 0.9517, Train Acc: 0.7333, Val Acc: 0.8000, Test Acc: 0.5333
# Epoch: 020, Loss: 0.9468, Train Acc: 0.8444, Val Acc: 0.9333, Test Acc: 0.7667
# Epoch: 021, Loss: 0.9459, Train Acc: 0.8667, Val Acc: 0.9333, Test Acc: 0.8333
# Epoch: 022, Loss: 0.9488, Train Acc: 0.8778, Val Acc: 0.9667, Test Acc: 0.8333
# Epoch: 023, Loss: 0.9209, Train Acc: 0.9111, Val Acc: 1.0000, Test Acc: 0.8667
# Epoch: 024, Loss: 0.9211, Train Acc: 0.9333, Val Acc: 1.0000, Test Acc: 0.8667
# Epoch: 025, Loss: 0.9210, Train Acc: 0.9333, Val Acc: 1.0000, Test Acc: 0.9000
# Epoch: 026, Loss: 0.9215, Train Acc: 0.9556, Val Acc: 1.0000, Test Acc: 0.9000
# Epoch: 027, Loss: 0.8885, Train Acc: 0.9556, Val Acc: 1.0000, Test Acc: 0.9000
# Epoch: 028, Loss: 0.8949, Train Acc: 0.9556, Val Acc: 1.0000, Test Acc: 0.9000
# Epoch: 029, Loss: 0.8983, Train Acc: 0.9667, Val Acc: 1.0000, Test Acc: 0.9333
# Epoch: 030, Loss: 0.8940, Train Acc: 0.9667, Val Acc: 1.0000, Test Acc: 0.9333
# Epoch: 031, Loss: 0.8846, Train Acc: 0.9778, Val Acc: 1.0000, Test Acc: 0.9333
# Epoch: 032, Loss: 0.8767, Train Acc: 0.9778, Val Acc: 1.0000, Test Acc: 0.9333
# Epoch: 033, Loss: 0.9033, Train Acc: 0.9778, Val Acc: 1.0000, Test Acc: 0.9333
# Epoch: 034, Loss: 0.8701, Train Acc: 0.9778, Val Acc: 1.0000, Test Acc: 0.9333
# Epoch: 035, Loss: 0.8720, Train Acc: 0.9778, Val Acc: 1.0000, Test Acc: 0.9333
# Epoch: 036, Loss: 0.8581, Train Acc: 0.9778, Val Acc: 1.0000, Test Acc: 0.9333
# Epoch: 037, Loss: 0.8376, Train Acc: 0.9778, Val Acc: 1.0000, Test Acc: 0.9333
# Epoch: 038, Loss: 0.8663, Train Acc: 0.9778, Val Acc: 1.0000, Test Acc: 0.9333
# Epoch: 039, Loss: 0.8627, Train Acc: 0.9778, Val Acc: 1.0000, Test Acc: 0.9333
# Epoch: 040, Loss: 0.8117, Train Acc: 0.9778, Val Acc: 1.0000, Test Acc: 0.9333
# Epoch: 041, Loss: 0.8098, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 042, Loss: 0.7968, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 043, Loss: 0.8196, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 044, Loss: 0.8209, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 045, Loss: 0.7952, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 046, Loss: 0.8007, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 047, Loss: 0.7774, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 048, Loss: 0.7842, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 049, Loss: 0.7675, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 050, Loss: 0.7921, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 051, Loss: 0.7712, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 052, Loss: 0.7729, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 053, Loss: 0.7832, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 054, Loss: 0.7482, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 055, Loss: 0.7414, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 056, Loss: 0.7740, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 057, Loss: 0.7207, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 058, Loss: 0.7275, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 059, Loss: 0.7252, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 060, Loss: 0.7395, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 061, Loss: 0.7240, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 062, Loss: 0.7034, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 063, Loss: 0.6985, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 064, Loss: 0.7043, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 065, Loss: 0.7015, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 066, Loss: 0.6944, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 067, Loss: 0.6475, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 068, Loss: 0.6725, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 069, Loss: 0.6802, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 070, Loss: 0.6571, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 071, Loss: 0.6582, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 072, Loss: 0.6292, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 073, Loss: 0.6494, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 074, Loss: 0.6545, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 075, Loss: 0.6438, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 076, Loss: 0.6007, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 077, Loss: 0.6288, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 078, Loss: 0.6305, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 079, Loss: 0.6333, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 080, Loss: 0.5993, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 081, Loss: 0.6366, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 082, Loss: 0.6075, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 083, Loss: 0.5989, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 084, Loss: 0.5688, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 085, Loss: 0.6131, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 086, Loss: 0.5582, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 087, Loss: 0.5425, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 088, Loss: 0.5645, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 089, Loss: 0.5655, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 090, Loss: 0.5834, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 091, Loss: 0.5379, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 092, Loss: 0.5651, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 093, Loss: 0.5460, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 094, Loss: 0.5468, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 095, Loss: 0.5405, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 096, Loss: 0.5308, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 097, Loss: 0.5249, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 098, Loss: 0.5023, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 099, Loss: 0.4978, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 100, Loss: 0.5162, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# --- 训练完成 ---
# 最终测试集准确率: 1.0000
#
# TensorBoard 日志已写入 'runs' 文件夹。
