# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.data import Data
from torch_geometric.utils import dense_to_sparse
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from torch.utils.tensorboard import SummaryWriter

# --- 实例化 SummaryWriter ---
# 创建一个新的文件夹来存放本次实验的日志
writer = SummaryWriter('../runs/7_3_iris_fca_gnn_multi_curve')

# --- 数据加载与预处理 (与之前相同) ---
features_path = '../data/iris.data.cleaned.csv'
x_numpy = np.loadtxt(features_path, delimiter=',')
x = torch.tensor(x_numpy, dtype=torch.float)

adj_matrix_path = '../data/iris_A_negative_UG.csv'
a_plus_numpy = np.loadtxt(adj_matrix_path, delimiter=',')
a_plus = torch.tensor(a_plus_numpy, dtype=torch.float)
threshold = 40000
a_plus[a_plus <= threshold] = 0
a_plus.fill_diagonal_(0)
edge_index, edge_attr = dense_to_sparse(a_plus)

labels_path = '../data/iris.data'
column_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
iris_df = pd.read_csv(labels_path, header=None, names=column_names)
species_labels = iris_df['species'].values
encoder = LabelEncoder()
y_numpy = encoder.fit_transform(species_labels)
y = torch.tensor(y_numpy, dtype=torch.long)

num_nodes = x.shape[0]
if num_nodes != len(y):
    y = y[:num_nodes]

data = Data(x=x, edge_index=edge_index, edge_attr=edge_attr, y=y)

# --- 数据划分：训练(60%)、验证(20%)、测试(20%) ---
num_train = int(num_nodes * 0.6)
num_val = int(num_nodes * 0.2)
num_test = num_nodes - num_train - num_val
indices = torch.randperm(num_nodes)

data.train_mask = torch.zeros(num_nodes, dtype=torch.bool)
data.val_mask = torch.zeros(num_nodes, dtype=torch.bool)
data.test_mask = torch.zeros(num_nodes, dtype=torch.bool)
data.train_mask[indices[:num_train]] = True
data.val_mask[indices[num_train:num_train + num_val]] = True
data.test_mask[indices[num_train + num_val:]] = True

print("--- 数据加载完成 ---")
print(f"训练节点数: {data.train_mask.sum().item()}, 验证节点数: {data.val_mask.sum().item()}, 测试节点数: {data.test_mask.sum().item()}")

# --- GNN 模型定义 (与之前相同) ---
class GCN(torch.nn.Module):
    def __init__(self, num_node_features, num_classes):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(num_node_features, 16)
        self.conv2 = GCNConv(16, num_classes)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.conv2(x, edge_index)
        return x

# --- 训练与评估 ---
model = GCN(num_node_features=data.num_node_features, num_classes=len(np.unique(y_numpy)))
optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-4)
criterion = torch.nn.CrossEntropyLoss()

def train(epoch):
    model.train()
    optimizer.zero_grad()
    out = model(data.x, data.edge_index)
    loss = criterion(out[data.train_mask], data.y[data.train_mask])
    loss.backward()
    optimizer.step()
    # 只记录训练集的Loss
    writer.add_scalar('Loss/train', loss.item(), epoch)
    return loss.item()

# --- 【修改】评估函数现在也计算并记录Loss ---
def evaluate(epoch):
    model.eval()
    with torch.no_grad():
        out = model(data.x, data.edge_index)
        pred = out.argmax(dim=1)
        
        # --- 计算 Loss ---
        train_loss = criterion(out[data.train_mask], data.y[data.train_mask])
        val_loss = criterion(out[data.val_mask], data.y[data.val_mask])
        test_loss = criterion(out[data.test_mask], data.y[data.test_mask])
        
        # --- 计算 Accuracy ---
        correct_train = pred[data.train_mask] == data.y[data.train_mask]
        train_acc = int(correct_train.sum()) / int(data.train_mask.sum())
        
        correct_val = pred[data.val_mask] == data.y[data.val_mask]
        val_acc = int(correct_val.sum()) / int(data.val_mask.sum())
        
        correct_test = pred[data.test_mask] == data.y[data.test_mask]
        test_acc = int(correct_test.sum()) / int(data.test_mask.sum())

        # --- 将所有指标记录到 TensorBoard ---
        # 使用相同的 "Loss" 标签头，将三条线画在同一个Loss图里
        writer.add_scalar('Loss/validation', val_loss.item(), epoch)
        writer.add_scalar('Loss/test', test_loss.item(), epoch)
        
        # 使用相同的 "Accuracy" 标签头，将三条线画在同一个Accuracy图里
        writer.add_scalar('Accuracy/train', train_acc, epoch)
        writer.add_scalar('Accuracy/validation', val_acc, epoch)
        writer.add_scalar('Accuracy/test', test_acc, epoch)
        
        return train_acc, val_acc, test_acc, train_loss.item()

print("\n--- 开始训练 ---")
for epoch in range(1, 101):
    # train()函数现在只返回loss，不再计算精度，避免重复计算
    loss = train(epoch) 
    
    # 在每个 epoch 后都进行评估
    train_acc, val_acc, test_acc, _ = evaluate(epoch)
    
    if epoch % 1 == 0:
        print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}, Train Acc: {train_acc:.4f}, Val Acc: {val_acc:.4f}, Test Acc: {test_acc:.4f}')

writer.close()

# 获取最后一个 epoch 的测试精度作为最终结果
final_test_acc = evaluate(100)[2] 
print(f'--- 训练完成 ---')
print(f'最终测试集准确率: {final_test_acc:.4f}')
print("\nTensorBoard 日志已写入 'runs' 文件夹。")
# Out:
# --- 数据加载完成 ---
# 训练节点数: 90, 验证节点数: 30, 测试节点数: 30
#
# --- 开始训练 ---
# Epoch: 001, Loss: 1.1492, Train Acc: 0.3000, Val Acc: 0.4000, Test Acc: 0.1667
# Epoch: 002, Loss: 1.1392, Train Acc: 0.3111, Val Acc: 0.4333, Test Acc: 0.1667
# Epoch: 003, Loss: 1.1666, Train Acc: 0.3444, Val Acc: 0.4333, Test Acc: 0.1667
# Epoch: 004, Loss: 1.1512, Train Acc: 0.3556, Val Acc: 0.4667, Test Acc: 0.1667
# Epoch: 005, Loss: 1.1302, Train Acc: 0.3667, Val Acc: 0.4667, Test Acc: 0.1667
# Epoch: 006, Loss: 1.1356, Train Acc: 0.3667, Val Acc: 0.5333, Test Acc: 0.1667
# Epoch: 007, Loss: 1.1434, Train Acc: 0.4000, Val Acc: 0.5667, Test Acc: 0.1667
# Epoch: 008, Loss: 1.1088, Train Acc: 0.4444, Val Acc: 0.5667, Test Acc: 0.2667
# Epoch: 009, Loss: 1.1208, Train Acc: 0.4889, Val Acc: 0.6000, Test Acc: 0.4333
# Epoch: 010, Loss: 1.1150, Train Acc: 0.5333, Val Acc: 0.6333, Test Acc: 0.4333
# Epoch: 011, Loss: 1.0903, Train Acc: 0.5333, Val Acc: 0.6333, Test Acc: 0.4333
# Epoch: 012, Loss: 1.0677, Train Acc: 0.5333, Val Acc: 0.6333, Test Acc: 0.4333
# Epoch: 013, Loss: 1.0578, Train Acc: 0.5333, Val Acc: 0.6333, Test Acc: 0.5333
# Epoch: 014, Loss: 1.1003, Train Acc: 0.5556, Val Acc: 0.6333, Test Acc: 0.5333
# Epoch: 015, Loss: 1.0454, Train Acc: 0.5556, Val Acc: 0.6333, Test Acc: 0.5333
# Epoch: 016, Loss: 1.0197, Train Acc: 0.5667, Val Acc: 0.6333, Test Acc: 0.5333
# Epoch: 017, Loss: 1.0584, Train Acc: 0.5667, Val Acc: 0.6333, Test Acc: 0.5667
# Epoch: 018, Loss: 1.0810, Train Acc: 0.5778, Val Acc: 0.6667, Test Acc: 0.5667
# Epoch: 019, Loss: 1.0252, Train Acc: 0.5889, Val Acc: 0.6667, Test Acc: 0.5667
# Epoch: 020, Loss: 1.0321, Train Acc: 0.5889, Val Acc: 0.6667, Test Acc: 0.5667
# Epoch: 021, Loss: 1.0517, Train Acc: 0.6111, Val Acc: 0.6667, Test Acc: 0.5667
# Epoch: 022, Loss: 1.0223, Train Acc: 0.6111, Val Acc: 0.7000, Test Acc: 0.6000
# Epoch: 023, Loss: 1.0141, Train Acc: 0.6111, Val Acc: 0.7000, Test Acc: 0.6000
# Epoch: 024, Loss: 0.9840, Train Acc: 0.6111, Val Acc: 0.7333, Test Acc: 0.6000
# Epoch: 025, Loss: 1.0213, Train Acc: 0.6333, Val Acc: 0.7667, Test Acc: 0.6000
# Epoch: 026, Loss: 1.0031, Train Acc: 0.6444, Val Acc: 0.8333, Test Acc: 0.6333
# Epoch: 027, Loss: 0.9225, Train Acc: 0.6444, Val Acc: 0.8667, Test Acc: 0.6333
# Epoch: 028, Loss: 0.9581, Train Acc: 0.6556, Val Acc: 0.8667, Test Acc: 0.6667
# Epoch: 029, Loss: 0.9890, Train Acc: 0.6778, Val Acc: 0.8667, Test Acc: 0.7000
# Epoch: 030, Loss: 0.9167, Train Acc: 0.6778, Val Acc: 0.8667, Test Acc: 0.7000
# Epoch: 031, Loss: 0.9513, Train Acc: 0.6778, Val Acc: 0.8667, Test Acc: 0.7667
# Epoch: 032, Loss: 0.9580, Train Acc: 0.7000, Val Acc: 0.8667, Test Acc: 0.7667
# Epoch: 033, Loss: 0.9597, Train Acc: 0.7222, Val Acc: 0.8667, Test Acc: 0.7667
# Epoch: 034, Loss: 0.9080, Train Acc: 0.7556, Val Acc: 0.8667, Test Acc: 0.8000
# Epoch: 035, Loss: 0.9698, Train Acc: 0.7556, Val Acc: 0.8667, Test Acc: 0.8333
# Epoch: 036, Loss: 0.9395, Train Acc: 0.7556, Val Acc: 0.8667, Test Acc: 0.8333
# Epoch: 037, Loss: 0.9119, Train Acc: 0.7778, Val Acc: 0.9000, Test Acc: 0.8333
# Epoch: 038, Loss: 0.9582, Train Acc: 0.7778, Val Acc: 0.9000, Test Acc: 0.8333
# Epoch: 039, Loss: 0.8936, Train Acc: 0.7778, Val Acc: 0.9000, Test Acc: 0.8333
# Epoch: 040, Loss: 0.8921, Train Acc: 0.8000, Val Acc: 0.9000, Test Acc: 0.8333
# Epoch: 041, Loss: 0.8822, Train Acc: 0.8222, Val Acc: 0.9000, Test Acc: 0.8333
# Epoch: 042, Loss: 0.9090, Train Acc: 0.8444, Val Acc: 0.9000, Test Acc: 0.8333
# Epoch: 043, Loss: 0.8552, Train Acc: 0.8889, Val Acc: 0.9000, Test Acc: 0.8333
# Epoch: 044, Loss: 0.8516, Train Acc: 0.8889, Val Acc: 0.9333, Test Acc: 0.8333
# Epoch: 045, Loss: 0.8927, Train Acc: 0.8889, Val Acc: 0.9333, Test Acc: 0.8667
# Epoch: 046, Loss: 0.8823, Train Acc: 0.8889, Val Acc: 0.9333, Test Acc: 0.8667
# Epoch: 047, Loss: 0.8678, Train Acc: 0.8889, Val Acc: 0.9333, Test Acc: 0.8667
# Epoch: 048, Loss: 0.8408, Train Acc: 0.8889, Val Acc: 0.9333, Test Acc: 0.8667
# Epoch: 049, Loss: 0.8209, Train Acc: 0.8889, Val Acc: 0.9333, Test Acc: 0.8667
# Epoch: 050, Loss: 0.8242, Train Acc: 0.8889, Val Acc: 0.9333, Test Acc: 0.8667
# Epoch: 051, Loss: 0.8441, Train Acc: 0.8889, Val Acc: 0.9333, Test Acc: 0.8667
# Epoch: 052, Loss: 0.8301, Train Acc: 0.8889, Val Acc: 0.9333, Test Acc: 0.8667
# Epoch: 053, Loss: 0.8371, Train Acc: 0.9000, Val Acc: 0.9333, Test Acc: 0.9000
# Epoch: 054, Loss: 0.8095, Train Acc: 0.9000, Val Acc: 0.9333, Test Acc: 0.9000
# Epoch: 055, Loss: 0.8035, Train Acc: 0.9000, Val Acc: 0.9333, Test Acc: 0.9000
# Epoch: 056, Loss: 0.8004, Train Acc: 0.9000, Val Acc: 0.9667, Test Acc: 0.9000
# Epoch: 057, Loss: 0.7849, Train Acc: 0.9000, Val Acc: 0.9667, Test Acc: 0.9000
# Epoch: 058, Loss: 0.7327, Train Acc: 0.9333, Val Acc: 0.9667, Test Acc: 0.9333
# Epoch: 059, Loss: 0.7909, Train Acc: 0.9333, Val Acc: 0.9667, Test Acc: 0.9333
# Epoch: 060, Loss: 0.7740, Train Acc: 0.9444, Val Acc: 0.9667, Test Acc: 0.9333
# Epoch: 061, Loss: 0.7977, Train Acc: 0.9444, Val Acc: 0.9667, Test Acc: 0.9333
# Epoch: 062, Loss: 0.7115, Train Acc: 0.9556, Val Acc: 0.9667, Test Acc: 0.9333
# Epoch: 063, Loss: 0.7025, Train Acc: 0.9556, Val Acc: 0.9667, Test Acc: 0.9333
# Epoch: 064, Loss: 0.7277, Train Acc: 0.9556, Val Acc: 0.9667, Test Acc: 0.9333
# Epoch: 065, Loss: 0.7136, Train Acc: 0.9667, Val Acc: 0.9667, Test Acc: 0.9333
# Epoch: 066, Loss: 0.6971, Train Acc: 0.9667, Val Acc: 0.9667, Test Acc: 0.9333
# Epoch: 067, Loss: 0.7439, Train Acc: 0.9667, Val Acc: 0.9667, Test Acc: 0.9333
# Epoch: 068, Loss: 0.6928, Train Acc: 0.9667, Val Acc: 0.9667, Test Acc: 0.9333
# Epoch: 069, Loss: 0.6810, Train Acc: 0.9667, Val Acc: 0.9667, Test Acc: 0.9333
# Epoch: 070, Loss: 0.6788, Train Acc: 0.9667, Val Acc: 0.9667, Test Acc: 0.9333
# Epoch: 071, Loss: 0.6465, Train Acc: 0.9667, Val Acc: 0.9667, Test Acc: 0.9333
# Epoch: 072, Loss: 0.6662, Train Acc: 0.9667, Val Acc: 0.9667, Test Acc: 0.9333
# Epoch: 073, Loss: 0.6857, Train Acc: 0.9778, Val Acc: 0.9667, Test Acc: 0.9333
# Epoch: 074, Loss: 0.6699, Train Acc: 0.9778, Val Acc: 0.9667, Test Acc: 0.9333
# Epoch: 075, Loss: 0.6353, Train Acc: 0.9778, Val Acc: 0.9667, Test Acc: 0.9333
# Epoch: 076, Loss: 0.6263, Train Acc: 0.9778, Val Acc: 0.9667, Test Acc: 0.9333
# Epoch: 077, Loss: 0.6782, Train Acc: 0.9778, Val Acc: 0.9667, Test Acc: 0.9333
# Epoch: 078, Loss: 0.6785, Train Acc: 0.9778, Val Acc: 0.9667, Test Acc: 0.9333
# Epoch: 079, Loss: 0.6671, Train Acc: 0.9889, Val Acc: 0.9667, Test Acc: 0.9333
# Epoch: 080, Loss: 0.5985, Train Acc: 0.9889, Val Acc: 0.9667, Test Acc: 0.9333
# Epoch: 081, Loss: 0.6308, Train Acc: 0.9889, Val Acc: 0.9667, Test Acc: 0.9333
# Epoch: 082, Loss: 0.5855, Train Acc: 0.9889, Val Acc: 0.9667, Test Acc: 0.9333
# Epoch: 083, Loss: 0.5903, Train Acc: 0.9889, Val Acc: 0.9667, Test Acc: 0.9333
# Epoch: 084, Loss: 0.5926, Train Acc: 1.0000, Val Acc: 0.9667, Test Acc: 0.9333
# Epoch: 085, Loss: 0.6331, Train Acc: 1.0000, Val Acc: 0.9667, Test Acc: 0.9333
# Epoch: 086, Loss: 0.5965, Train Acc: 1.0000, Val Acc: 0.9667, Test Acc: 0.9333
# Epoch: 087, Loss: 0.5890, Train Acc: 1.0000, Val Acc: 0.9667, Test Acc: 0.9333
# Epoch: 088, Loss: 0.6074, Train Acc: 1.0000, Val Acc: 0.9667, Test Acc: 0.9333
# Epoch: 089, Loss: 0.5724, Train Acc: 1.0000, Val Acc: 0.9667, Test Acc: 0.9667
# Epoch: 090, Loss: 0.6212, Train Acc: 1.0000, Val Acc: 0.9667, Test Acc: 0.9667
# Epoch: 091, Loss: 0.5845, Train Acc: 1.0000, Val Acc: 0.9667, Test Acc: 0.9667
# Epoch: 092, Loss: 0.5573, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 093, Loss: 0.5790, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 094, Loss: 0.5864, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 095, Loss: 0.4882, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 096, Loss: 0.5255, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 097, Loss: 0.5181, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 098, Loss: 0.5468, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 099, Loss: 0.5289, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 100, Loss: 0.5213, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# --- 训练完成 ---
# 最终测试集准确率: 0.9667
#
# TensorBoard 日志已写入 'runs' 文件夹。
