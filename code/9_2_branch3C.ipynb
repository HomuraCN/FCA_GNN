# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.data import Data
from torch_geometric.utils import dense_to_sparse
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from torch.utils.tensorboard import SummaryWriter

# --- 实例化 SummaryWriter ---
writer = SummaryWriter('../runs/9_2_iris_dual_concept_gnn')

# --- 1. 数据加载与预处理 ---

# a) 加载节点特征 (两个分支共享相同的节点特征)
features_path = '../data/iris.data.cleaned.csv'
x_numpy = np.loadtxt(features_path, delimiter=',')
x_features = torch.tensor(x_numpy, dtype=torch.float)
num_nodes = x_features.shape[0]

# b) 加载并处理正概念格邻接矩阵 (分支一)
adj_matrix_pos_path = '../data/iris_A_plus_UG.csv'
a_plus_pos_numpy = np.loadtxt(adj_matrix_pos_path, delimiter=',')
a_plus_pos = torch.tensor(a_plus_pos_numpy, dtype=torch.float)
threshold_pos = 25  # 保持与之前实验一致的阈值
a_plus_pos[a_plus_pos <= threshold_pos] = 0
a_plus_pos.fill_diagonal_(0)
edge_index_pos, edge_attr_pos = dense_to_sparse(a_plus_pos)
print(f"--- 正概念图 ---")
print(f"阈值化后保留 {torch.count_nonzero(a_plus_pos)} 条边。")


# c) 【新增】加载并处理负概念格邻接矩阵 (分支二)
adj_matrix_neg_path = '../data/iris_A_negative_UG.csv'
a_plus_neg_numpy = np.loadtxt(adj_matrix_neg_path, delimiter=',')
a_plus_neg = torch.tensor(a_plus_neg_numpy, dtype=torch.float)
threshold_neg = 40000  # 按照您的要求设置阈值
a_plus_neg[a_plus_neg <= threshold_neg] = 0
a_plus_neg.fill_diagonal_(0)
edge_index_neg, edge_attr_neg = dense_to_sparse(a_plus_neg)
print(f"--- 负概念图 ---")
print(f"阈值化后保留 {torch.count_nonzero(a_plus_neg)} 条边。")


# d) 加载标签 y
labels_path = '../data/iris.data'
column_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
iris_df = pd.read_csv(labels_path, header=None, names=column_names)
species_labels = iris_df['species'].values
encoder = LabelEncoder()
y_numpy = encoder.fit_transform(species_labels)
y = torch.tensor(y_numpy, dtype=torch.long)
if num_nodes != len(y):
    y = y[:num_nodes]

# e) 创建包含所有图信息的 Data 对象
data = Data(x=x_features, y=y,
            edge_index_pos=edge_index_pos, edge_attr_pos=edge_attr_pos,
            edge_index_neg=edge_index_neg, edge_attr_neg=edge_attr_neg)

# f) 数据划分
num_train = int(num_nodes * 0.6)
num_val = int(num_nodes * 0.2)
num_test = num_nodes - num_train - num_val
indices = torch.randperm(num_nodes)
data.train_mask = torch.zeros(num_nodes, dtype=torch.bool)
data.val_mask = torch.zeros(num_nodes, dtype=torch.bool)
data.test_mask = torch.zeros(num_nodes, dtype=torch.bool)
data.train_mask[indices[:num_train]] = True
data.val_mask[indices[num_train:num_train + num_val]] = True
data.test_mask[indices[num_train + num_val:]] = True

print("\n--- 数据加载完成 (双概念格分支模型) ---")
print(data)

# --- 2. 定义双概念格分支 GNN 模型 (DualConceptGCN) ---
class DualConceptGCN(nn.Module):
    def __init__(self, num_node_features, hidden_channels, num_classes):
        super(DualConceptGCN, self).__init__()
        
        # 分支一：处理正概念格图
        self.pos_conv = GCNConv(num_node_features, hidden_channels)
        
        # 分支二：处理负概念格图
        self.neg_conv = GCNConv(num_node_features, hidden_channels)
        
        # 融合层
        self.fusion_layer = nn.Linear(hidden_channels * 2, num_classes)

    def forward(self, x, edge_index_pos, edge_attr_pos, edge_index_neg, edge_attr_neg):
        # --- 分支一前向传播 (正概念图) ---
        h_pos = self.pos_conv(x, edge_index_pos, edge_attr_pos)
        h_pos = F.relu(h_pos)
        h_pos = F.dropout(h_pos, p=0.5, training=self.training)
        
        # --- 分支二前向传播 (负概念图) ---
        h_neg = self.neg_conv(x, edge_index_neg, edge_attr_neg)
        h_neg = F.relu(h_neg)
        h_neg = F.dropout(h_neg, p=0.5, training=self.training)
        
        # --- 特征融合 ---
        h_combined = torch.cat([h_pos, h_neg], dim=1)
        
        # --- 通过融合层得到最终输出 ---
        out = self.fusion_layer(h_combined)
        return out

# --- 3. 训练与评估 ---
HIDDEN_CHANNELS = 16
model = DualConceptGCN(num_node_features=data.num_node_features, 
                       hidden_channels=HIDDEN_CHANNELS, 
                       num_classes=len(np.unique(y_numpy)))

optimizer = torch.optim.Adam(model.parameters(), lr=0.005, weight_decay=5e-4)
criterion = torch.nn.CrossEntropyLoss()

def train(epoch):
    model.train()
    optimizer.zero_grad()
    out = model(data.x, data.edge_index_pos, data.edge_attr_pos, 
                data.edge_index_neg, data.edge_attr_neg)
    loss = criterion(out[data.train_mask], data.y[data.train_mask])
    loss.backward()
    optimizer.step()
    writer.add_scalar('Loss/train', loss.item(), epoch)
    return loss.item()

def evaluate(epoch):
    model.eval()
    with torch.no_grad():
        out = model(data.x, data.edge_index_pos, data.edge_attr_pos, 
                    data.edge_index_neg, data.edge_attr_neg)
        pred = out.argmax(dim=1)
        
        train_acc = (pred[data.train_mask] == data.y[data.train_mask]).sum().item() / data.train_mask.sum().item()
        val_acc = (pred[data.val_mask] == data.y[data.val_mask]).sum().item() / data.val_mask.sum().item()
        test_acc = (pred[data.test_mask] == data.y[data.test_mask]).sum().item() / data.test_mask.sum().item()

        writer.add_scalar('Accuracy/train', train_acc, epoch)
        writer.add_scalar('Accuracy/validation', val_acc, epoch)
        writer.add_scalar('Accuracy/test', test_acc, epoch)
        
        return train_acc, val_acc, test_acc

print("\n--- 开始训练 (双概念格分支 GNN) ---")
for epoch in range(1, 151):
    loss = train(epoch)
    if epoch % 1 == 0:
        train_acc, val_acc, test_acc = evaluate(epoch)
        print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}, Train Acc: {train_acc:.4f}, Val Acc: {val_acc:.4f}, Test Acc: {test_acc:.4f}')

writer.close()

final_test_acc = evaluate(150)[2]
print(f'--- 训练完成 ---')
print(f'最终测试集准确率 (双概念格分支 GNN): {final_test_acc:.4f}')
print("\nTensorBoard 日志已写入 'runs/iris_dual_concept_gnn' 文件夹。")
# Out:
# --- 正概念图 ---
# 阈值化后保留 192 条边。
# --- 负概念图 ---
# 阈值化后保留 306 条边。
#
# --- 数据加载完成 (双概念格分支模型) ---
# Data(x=[150, 126], y=[150], edge_index_pos=[2, 192], edge_attr_pos=[192], edge_index_neg=[2, 306], edge_attr_neg=[306], train_mask=[150], val_mask=[150], test_mask=[150])
#
# --- 开始训练 (双概念格分支 GNN) ---
# Epoch: 001, Loss: 1.0884, Train Acc: 0.5000, Val Acc: 0.3667, Test Acc: 0.3000
# Epoch: 002, Loss: 1.0604, Train Acc: 0.5556, Val Acc: 0.4333, Test Acc: 0.3333
# Epoch: 003, Loss: 1.0491, Train Acc: 0.5778, Val Acc: 0.4333, Test Acc: 0.4000
# Epoch: 004, Loss: 1.0262, Train Acc: 0.6222, Val Acc: 0.4667, Test Acc: 0.4000
# Epoch: 005, Loss: 1.0034, Train Acc: 0.6444, Val Acc: 0.5000, Test Acc: 0.4333
# Epoch: 006, Loss: 0.9701, Train Acc: 0.6889, Val Acc: 0.5333, Test Acc: 0.4667
# Epoch: 007, Loss: 0.9802, Train Acc: 0.7556, Val Acc: 0.6000, Test Acc: 0.5333
# Epoch: 008, Loss: 0.9264, Train Acc: 0.7889, Val Acc: 0.6333, Test Acc: 0.5333
# Epoch: 009, Loss: 0.8868, Train Acc: 0.8111, Val Acc: 0.6667, Test Acc: 0.5667
# Epoch: 010, Loss: 0.8667, Train Acc: 0.8778, Val Acc: 0.7667, Test Acc: 0.6667
# Epoch: 011, Loss: 0.8529, Train Acc: 0.9111, Val Acc: 0.8667, Test Acc: 0.7667
# Epoch: 012, Loss: 0.8301, Train Acc: 0.9444, Val Acc: 0.9000, Test Acc: 0.7667
# Epoch: 013, Loss: 0.7915, Train Acc: 0.9556, Val Acc: 0.9333, Test Acc: 0.8667
# Epoch: 014, Loss: 0.7452, Train Acc: 0.9778, Val Acc: 1.0000, Test Acc: 0.9000
# Epoch: 015, Loss: 0.7258, Train Acc: 0.9778, Val Acc: 1.0000, Test Acc: 0.9333
# Epoch: 016, Loss: 0.6927, Train Acc: 0.9778, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 017, Loss: 0.6485, Train Acc: 0.9778, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 018, Loss: 0.6094, Train Acc: 0.9889, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 019, Loss: 0.5687, Train Acc: 0.9889, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 020, Loss: 0.5462, Train Acc: 0.9889, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 021, Loss: 0.5418, Train Acc: 0.9889, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 022, Loss: 0.5141, Train Acc: 0.9889, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 023, Loss: 0.4313, Train Acc: 0.9889, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 024, Loss: 0.4566, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 025, Loss: 0.4038, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 026, Loss: 0.3372, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 027, Loss: 0.3659, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 028, Loss: 0.3106, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 029, Loss: 0.2661, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 030, Loss: 0.2384, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 031, Loss: 0.2399, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 032, Loss: 0.2266, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 033, Loss: 0.1906, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 034, Loss: 0.1717, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 035, Loss: 0.1889, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 036, Loss: 0.1412, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 037, Loss: 0.1235, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 038, Loss: 0.1412, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 039, Loss: 0.1234, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 040, Loss: 0.0926, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 041, Loss: 0.0837, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 042, Loss: 0.0893, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 043, Loss: 0.0811, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 044, Loss: 0.1019, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 045, Loss: 0.0755, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 046, Loss: 0.0748, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 047, Loss: 0.0699, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9333
# Epoch: 048, Loss: 0.0714, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 049, Loss: 0.0672, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 050, Loss: 0.0675, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 051, Loss: 0.0534, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 052, Loss: 0.0595, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 053, Loss: 0.0833, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 054, Loss: 0.0419, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 055, Loss: 0.0458, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 056, Loss: 0.0407, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 057, Loss: 0.0367, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 058, Loss: 0.0259, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 059, Loss: 0.0282, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 060, Loss: 0.0349, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 061, Loss: 0.0343, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 062, Loss: 0.0402, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 063, Loss: 0.0237, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 064, Loss: 0.0295, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 065, Loss: 0.0354, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 066, Loss: 0.0342, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 067, Loss: 0.0405, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 068, Loss: 0.0217, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 069, Loss: 0.0279, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 070, Loss: 0.0281, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 071, Loss: 0.0193, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 072, Loss: 0.0218, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 073, Loss: 0.0283, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 074, Loss: 0.0214, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 075, Loss: 0.0220, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 076, Loss: 0.0238, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 077, Loss: 0.0250, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 078, Loss: 0.0261, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 079, Loss: 0.0207, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 0.9667
# Epoch: 080, Loss: 0.0304, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 081, Loss: 0.0182, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 082, Loss: 0.0308, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 083, Loss: 0.0171, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 084, Loss: 0.0150, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 085, Loss: 0.0186, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 086, Loss: 0.0174, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 087, Loss: 0.0232, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 088, Loss: 0.0093, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 089, Loss: 0.0126, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 090, Loss: 0.0333, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 091, Loss: 0.0098, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 092, Loss: 0.0168, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 093, Loss: 0.0158, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 094, Loss: 0.0167, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 095, Loss: 0.0081, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 096, Loss: 0.0093, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 097, Loss: 0.0131, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 098, Loss: 0.0161, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 099, Loss: 0.0126, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 100, Loss: 0.0178, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 101, Loss: 0.0163, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 102, Loss: 0.0135, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 103, Loss: 0.0125, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 104, Loss: 0.0231, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 105, Loss: 0.0272, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 106, Loss: 0.0162, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 107, Loss: 0.0102, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 108, Loss: 0.0172, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 109, Loss: 0.0106, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 110, Loss: 0.0129, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 111, Loss: 0.0095, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 112, Loss: 0.0085, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 113, Loss: 0.0152, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 114, Loss: 0.0107, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 115, Loss: 0.0148, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 116, Loss: 0.0117, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 117, Loss: 0.0169, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 118, Loss: 0.0172, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 119, Loss: 0.0073, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 120, Loss: 0.0103, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 121, Loss: 0.0134, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 122, Loss: 0.0099, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 123, Loss: 0.0181, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 124, Loss: 0.0149, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 125, Loss: 0.0102, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 126, Loss: 0.0107, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 127, Loss: 0.0064, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 128, Loss: 0.0160, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 129, Loss: 0.0120, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 130, Loss: 0.0126, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 131, Loss: 0.0052, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 132, Loss: 0.0128, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 133, Loss: 0.0134, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 134, Loss: 0.0111, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 135, Loss: 0.0132, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 136, Loss: 0.0109, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 137, Loss: 0.0102, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 138, Loss: 0.0099, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 139, Loss: 0.0098, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 140, Loss: 0.0227, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 141, Loss: 0.0134, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 142, Loss: 0.0092, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 143, Loss: 0.0109, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 144, Loss: 0.0065, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 145, Loss: 0.0105, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 146, Loss: 0.0149, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 147, Loss: 0.0153, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 148, Loss: 0.0144, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 149, Loss: 0.0111, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# Epoch: 150, Loss: 0.0101, Train Acc: 1.0000, Val Acc: 1.0000, Test Acc: 1.0000
# --- 训练完成 ---
# 最终测试集准确率 (双概念格分支 GNN): 1.0000
#
# TensorBoard 日志已写入 'runs/iris_dual_concept_gnn' 文件夹。
